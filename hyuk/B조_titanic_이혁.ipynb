# %% [markdown]
# # 데이터 분석 어떻게 시작해야 하나요?
# [GUIDE, KOR, DG] How do I begin this analysis....
#
# ---
#
# 본 커널은, 2019 ML month 대구 튜토리얼을 위한 커널입니다.
#
#
#
# ## Contents
#
# 0. 데이터 분석 시작하기 앞서서
# 1. 데이터 셋 확인
# 2. 탐색적 데이터 분석 (EDA, Exploratory Data Analysis)
# 3. 특성 공학 (Feature Engineering)
# 4. 모델 개발 및 학습
#     1. scikit-learn을 사용한 RandomForest모델 개발
#     1. keras를 사용한 NN 모델 개발 (미완)
# 5. 모델 예측 및 평가
#     1. RandomForest 예측 및 평가
#     1. NN 예측 및 평가 (미완)
# 6. 결론
# 7. 어떻게 공부하는게 좋을까요?

# %% [markdown]
# ## References
#
# 해당 커널은 아래의 멋진 분석 커널을 참고하였습니다.
# 멋진 분석을 제공해준 모든 분들께 감사드립니다. 항상 많은 도움이 되고 있습니다.
#
# * [colab, 전태균님의 타이타닉 분석](https://colab.research.google.com/drive/1cqv5yD9uLHHrVFL-TGM9NPSD1ZyF4AC1#scrollTo=jwBNmHcw3w91)
# * [블로그, 이유한님의 타이타닉 분석 튜토리얼](http://kaggle-kr.tistory.com/17?category=821486)
# * [공개 커널, Keras를 이용한 간단한 모델 구현!](https://www.kaggle.com/everystep/keras)

# %% [markdown]
# ## 0. 데이터 분석하기 앞서서
# ---
# ### 이 튜토리얼은 캐글을 시작하기 위한 가이드 입니다.
#
# "데이터를 이런식으로 가지고 놀 수 있구나~" 정도의 수준입니다.
# 이 튜토리얼로 데이터 분석 전반적인 흐름을 잡고 어떤 식으로
# 공부해야 할지 가이드를 잡아 드리는 것이 목표입니다.
# 부족한 부분이 있으면 언제든 피드백 부탁드립니다! 항상 배우고 싶습니다..
#
# 꼭 튜토리얼이 끝나시면, 개인적으로 다른 분들의 커널을 보시고
# 따라 해보시면서 다양하고 재밌는 인사이트를 얻으시길 기원합니다!
# 즐거운 캐글 되세요!
#
# ### 일단 따라서 작성하고 제출해보세요!
# *"Done is better than perfect!"*
#
# 사람마다 학습하고 적용하는 방법은 다르겠지만, 저는 먼저
# 해보고 재미를 느끼는 부류(?)입니다. 안에 있는 코드를 모두 이해하고
# 개발하기엔 너무 공부해야 할 양이 많으며 시작이 느려지고
# 동기가 약해지는 경험을 했습니다.
#
# 그래서 추천하자면, 기본과 실전을 동시에 하라고 추천드리고 싶습니다.
# 캐글은 개인이 분석한 커널을 공개하는 문화가 잘 형성되어 있습니다.
# 해당 커널을 따라해보고 제출을 해보고 모델을 튜닝하고 다시 제출하고...
# 이렇게 각종 점수를 눈에서 보면서 개발하니 재미를 느낄 수 있었습니다.
#
# 일단 따라서 작성하고 제출하고, 점수를 눈으로 보시면 재미를 느낄 수 있으실거라 생각합니다!!
#
# ### 왜 처음 시작이 타이타닉 이죠?
#
# 만약 데이터 사이언스, 머신러닝 또는 캐글에서 어떤 것을 해야하는 지
# 잘 모르는 newbie 라면, 타이타닉을 하시는 게 가장 좋은 선택입니다.
# 데이터 분석 전체 프로세스를 빠르게 경험하실 수 있으며,
# 접근하기 좋은 Binary Classification (0 혹은 1을 예측하는) 문제이기 때문입니다.
#
# ### 본 튜토리얼에선 파이썬의 다음과 같은 도구를 사용할 것입니다.
#
# * 여러 시각화 도구 : matplotlib, seaborn, plotly
# * 데이터 분석 도구 : pandas, numpy
# * 모델 개발 도구 : sklearn, keras
#
# ###  해당 커널은 다음과 같은 프로세스로 진행됩니다.
#
# 1. 데이터 셋 확인
#     * 데이터가 어떻게 구성되어 있는지 확인합니다.
#     * 대부분의 캐글 데이터들은 잘 정제되어 있습니다.
#     하지만 가끔 null data가 존재합니다. 이를 확인하고, 향후 수정합니다.
# 2. 탐색적 데이터 분석 (EDA, Exploratory Data Analysis)
#     * 여러 feature 들을 개별적으로 분석하고, feature 들 간의 상관관계를 확인합니다.
#     여러 시각화 툴을 사용하여 insight를 얻습니다.
# 3. 특성 공학 (Feature Engineering)
#     * 모델을 세우기에 앞서, 모델의 성능을 높일 수 있도록 feature 들을 engineering 합니다.
#     one-hot encoding, class로 나누기, 구간으로 나누기, 텍스트 데이터 처리 등을 합니다.
# 4. 모델 개발 및 학습
#     * sklearn, keras 을 사용해 모델을 만듭니다. 파이썬에서 머신러닝을 할 때는 sklearn 을
#     사용하면 수많은 알고리즘을 일관된 문법으로 사용할 수 있습니다. 또 keras는 딥러닝 개발
#     할 때 모델에 집중할 수 있도록 해줍니다. 물론 딥러닝을 위해 tensorflow, pytorch 등을
#     사용할 수 도 있습니다. 그리고 학습된 모델이 어떤 것을 학습하였는 지 확인해봅니다
# 5. 모델 예측 및 평가
#     * Train set 을 가지고 모델을 학습시킨 후, Test set 을 가지고 prediction 합니다.
#     그리고 예측 성능이 원하는 수준인지 판단합니다.
#     풀려는 문제에 따라 모델을 평가하는 방식도 달라집니다.
#
# ### 그럼 시작해 보도록 하겠습니다!
#
# > **Tip**:
# > 그대로 따라 써보는 것도 좋지만, 궁금하면 `print()`로 출력해보고 확인 해보시는 습관을 가지는게 좋은 것 같습니다.

# %% [markdown]
# ## 1. 데이터 셋 확인
# ---
# 일단 필요한 패키지(라이브러리)를 import 합니다.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
import sklearn

plt.style.use('seaborn')
sns.set(font_scale=2.5) # 이 두줄은 본 필자가 항상 쓰는 방법입니다. matplotlib 의 기본 scheme 말고 seaborn scheme 을 세팅하고, 일일이 graph 의 font size 를 지정할 필요 없이 seaborn 의 font_scale 을 사용하면 편합니다.
import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore') # 워닝 메세지를 생략해 줍니다. 차후 버전관리를 위해 필요한 정보라고 생각하시면 주석처리 하시면 됩니다.

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
os.listdir("../input")
# Out:
# ['sample_submission.csv', 'train.csv', 'test.csv']

# %% [markdown]
# input 경로에 있는 파일 리스트를 확인해 보니 위와 같이 3개가 나옴을 볼 수 있습니다.
# 각 파일의 역할은 다음과 같습니다.
#
# * `train.csv` : 학습에 이용하는 파일 입니다.
# * `test.csv` : 우리가 학습한 모델을 가지고 예측해야하는 파일입니다.
# * `sample_submission.csv` : 예측하고 해당 파일 폼에 맞추어 캐글에 제출해야 합니다.
#
# `pandas`를 사용해 각 파일을 로드해 보도록 하겠습니다.

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
df_submit = pd.read_csv('../input/sample_submission.csv')

# %%
df_train.shape, df_test.shape, df_submit.shape
# Out:
# ((891, 12), (418, 11), (418, 2))

# %% [markdown]
# 각 파일을 로드하고 각 파일의 크기를 확인해 보니,
# train할 데이터 수는 891개,
# test(제출해야)할 데이터 수는 418개를 확인해 볼 수 있습니다.

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# column(feature)는 총 12개로 이루어져 있으며,
# 학습에 사용해야 할 feature는 11개,
# 예측해야 할 feature는 `Survived`입니다.

# %%
df_submit.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %% [markdown]
# submit 파일은 2개의 칼럼만 있으면 됩니다.
# 어떤 사람인지 구분하는 `PassengerID`와,
# 해당 사람이 살았는지 죽었는지 구분하는 `Survived`만 제출하면 됩니다.
#
# 각 파일을 한번 출력해보겠습니다.

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         S
# 1            2         1       1    ...     71.2833   C85         C
# 2            3         1       3    ...      7.9250   NaN         S
# 3            4         1       1    ...     53.1000  C123         S
# 4            5         0       3    ...      8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df_test.head()
# Out:
#    PassengerId  Pclass   ...    Cabin Embarked
# 0          892       3   ...      NaN        Q
# 1          893       3   ...      NaN        S
# 2          894       2   ...      NaN        Q
# 3          895       3   ...      NaN        S
# 4          896       3   ...      NaN        S
#
# [5 rows x 11 columns]

# %%
df_submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %% [markdown]
# 우리가 다루는 문제에서 feature는 Pclass, Age, SibSp, Parch, Fare 이며, 예측하려는 target label 은 Survived 입니다.
#
# ### 타이타닉 데이터 Feature 설명
#
# * survival - 생존유무, target 값. (0 = 사망, 1 = 생존)
# * pclass - 티켓 클래스. (1 = 1st, 2 = 2nd, 3 = 3rd)
# * sex - 성별
# * Age - 나이(세)
# * sibsp - 함께 탑승한 형제자매, 배우자 수 총합
# * parch - 함께 탑승한 부모, 자녀 수 총합
# * ticket - 티켓 넘버
# * fare - 탑승 요금
# * cabin - 객실 넘버
# * bembarked - 탑승 항구
#
# ### 각 Feature types

# %%
df_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# pandas dataframe 에는 describe() 메소드가 있는 데, 이를 쓰면 각 feature 가 가진 통계치들을 반환해줍니다.

# %%
df_train.describe()
# Out:
#        PassengerId    Survived     ...           Parch        Fare
# count   891.000000  891.000000     ...      891.000000  891.000000
# mean    446.000000    0.383838     ...        0.381594   32.204208
# std     257.353842    0.486592     ...        0.806057   49.693429
# min       1.000000    0.000000     ...        0.000000    0.000000
# 25%     223.500000    0.000000     ...        0.000000    7.910400
# 50%     446.000000    0.000000     ...        0.000000   14.454200
# 75%     668.500000    1.000000     ...        0.000000   31.000000
# max     891.000000    1.000000     ...        6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass     ...           Parch        Fare
# count   418.000000  418.000000     ...      418.000000  417.000000
# mean   1100.500000    2.265550     ...        0.392344   35.627188
# std     120.810458    0.841838     ...        0.981429   55.907576
# min     892.000000    1.000000     ...        0.000000    0.000000
# 25%     996.250000    1.000000     ...        0.000000    7.895800
# 50%    1100.500000    3.000000     ...        0.000000   14.454200
# 75%    1204.750000    3.000000     ...        0.000000   31.500000
# max    1309.000000    3.000000     ...        9.000000  512.329200
#
# [8 rows x 6 columns]

# %% [markdown]
# 흠.. 데이터를 보니 칼럼 count값이 다른 feature가 보입니다.
# 결측치(Null)가 있는 것으로 보이는데 한번 알아보도록 하겠습니다.
#
# ### **1.1 결측치(Null Data) 확인**

# %%
df_train.isnull().sum() / df_train.shape[0]
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df_test.isnull().sum() / df_test.shape[0]
# Out:
# PassengerId    0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.205742
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.002392
# Cabin          0.782297
# Embarked       0.000000
# dtype: float64

# %% [markdown]
# train set과 test set에 비슷하게 `Age` 피쳐에 약 20%, `Cabin` 피쳐에 약 80%의
# 결측치가 있음을 확인할 수 있습니다.
#
# ### **1.2 Target Label, `Survived` 확인**
#
# target label 이 어떤 distribution 을 가지고 있는 지 확인해봐야 합니다.
# 지금 같은 binary classification 문제의 경우에서,
# 1과 0의 분포가 어떠냐에 따라 모델의 평가 방법이 달라 질 수 있습니다.

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()

# %% [markdown]
# target label 의 분포가 제법 균일(balanced)합니다.
# 불균일한 경우, 예를 들어서 100중 1이 99, 0이 1개인 경우에는
# 만약 모델이 모든것을 1이라 해도 정확도가 99%가 나오게 됩니다.
# 0을 찾는 문제라면 이 모델은 원하는 결과를 줄 수 없게 됩니다.
# 지금 문제에서는 그렇지 않으니 계속 진행하겠습니다.

# %% [markdown]
# ## 2. 탐색적 데이터 분석 (EDA, Exploratory Data Analysis)
# ---
# 이제 본격적으로 데이터 분석을 해보겠습니다.
# 데이터는 매우 많습니다. 이 많은 데이터 안에 숨겨진
# 사실을 찾기 위해선 적절한 시각화가 필요합니다.
#
# 시각화 라이브러리는 matplotlib, seaborn, plotly 등이 b있습니다.
# 특정 목적에 맞는 소스코드를 정리해두어 필요할 때마다 참고하면 편합니다
#
# ### **2.1 Pcalss**
# 먼저 Pclass 에 대해서 살펴보겠습니다.
#
# * Pclass는 서수형 데이터입니다.
# 즉, 카테고리이면서 순서가 있는 데이터 타입입니다.
# 먼저 Pclass 에 따른 생존률의 차이를 살펴보겠습니다.
# * 엑셀의 피벗 차트와 유사한 작업을 하게 되는데,
# pandas dataframe 에서는 `groupby` 를 사용하면 쉽게 할 수 있습니다.
# 또한 `pivot` 이라는 메소드도 있습니다.
# * `Pclass`,`Survived` 를 가져온 후, pclass 로 묶습니다.
# 그러고 나면 각 pclass 마다 0, 1 이 count가 되는데,
# 이를 평균내면 각 pclass 별 생존률이 나옵니다
# * 아래와 같이 count() 를 하면, 각 class 에 몇명이 있는 지
# 확인할 수 있으며, sum() 을 하면, 216 명중 생존한(survived=1)
# 사람의 총합을 주게 됩니다

# %%
# pclass 그룹 별 데이터 카운트
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
# pclass 그룹 별 생존자 수 합
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
# 위와 같은 작업을 crosstab으로 편하게 할 수 있습니다.
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
# mean은 생존률을 구하게 할 수 있습니다.
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
# 이를 시각화 해보았습니다.
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().plot.bar()

# %% [markdown]
# 우리는 생존에 Pclass 가 큰 영향을 미친다고 생각해볼 수 있으며,
# 나중에 모델을 세울 때 이 feature 를 사용하는 것이 좋을 것이라 판단할 수 있습니다.
#
# ### **2.2 Sex**

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %% [markdown]
# 보시다시피, 여자가 생존할 확률이 높습니다.
# Pclass 와 마찬가지로, Sex 도 예측 모델에 쓰일 중요한 feature 임을 알 수 있습니다

# %% [markdown]
# ### **2.3 Both Sex and Pclass**
#
# 이번에는 Sex, Pclass 두가지에 관하여 생존이 어떻게 달라지는 지 확인해 봅시다

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, 
               size=6, aspect=1.5)

# %% [markdown]
# 모든 클래스에서 female 이 살 확률이 male 보다 높은 걸 알 수 있습니다.

# %% [markdown]
# ### **2.4 Age**

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %% [markdown]
# 해당 히스토그램을 보시면 어린 나이(약 15세 미만) 구간에서
# 생존률이 상대적으로 높음을 확인할 수 있습니다.b

# %%
# Age distribution withing classes
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# 위의 그래프 클래스가 높아질 수록, 나이 연령대가 높아짐을 확인할 수 있습니다.
#
# 나이대가 높아질 수록 생존확률이 어떻게 달라지는지 알고 싶어져,
# 누적 확률을 활용한 시각화를 해보았습니다.

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))
    
plt.figure(figsize=(7, 7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# 나이가 어릴 수록 생존률이 확실히 높은것을 확인할 수 있습니다.
# 이를 통해 나이도 중요한 피쳐임을 확인할 수 있습니다.

# %% [markdown]
# 지금까지 얻은 분석을 종합하자면,
#
# * 여자이거나
# * 나이가 어리고,
# * 클래스가 높을 수록
#
# 생존확률이 높음을 확인할 수 있습니다.

# %% [markdown]
# ### **2.5 Embarked**
#
# Embarked는 탑승한 항구를 나타냅니다.

# %%
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)

# %% [markdown]
# 탑승한 곳에 따라 생존률의 차이가 많이 보이지는 않지만,
# 그래도 차이가 있으니 피쳐로 사용해보겠습니다.
#
# 그럼 다른 피쳐와의 상관관계도 한번 알아보도록 하겠습니다.

# %%
f,ax=plt.subplots(2, 2, figsize=(20,15))
sns.countplot('Embarked', data=df_train, ax=ax[0,0])
ax[0,0].set_title('(1) No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=df_train, ax=ax[0,1])
ax[0,1].set_title('(2) Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=df_train, ax=ax[1,0])
ax[1,0].set_title('(3) Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=df_train, ax=ax[1,1])
ax[1,1].set_title('(4) Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# * Figure(1) - 전체적으로 봤을 때, S 에서 가장 많은 사람이 탑승했습니다.
# * Figure(2) - C와 Q 는 남녀의 비율이 비슷하고, S는 남자가 더 많습니다.
# * Figure(3) - 생존확률이 S 경우 많이 낮은 걸 볼 수 있습니다. (이전 그래프에서 봤었습니다)
# * Figure(4) - Class 로 split 해서 보니, C가 생존확률이 높은건 클래스가 높은 사람이 많이 타서 그렇습니다. S는 3rd class 가 많아서 생존확률이 낮게 나옵니다.

# %% [markdown]
# ### **2.6 Family - SibSp(형제 자매) + Parch(부모, 자녀)**
#
# `SibSp`와 `Parch`를 합치면 함께 탑승한 가족의 수가 될 것입니다.
# 이 두 피쳐를 더해서 새로운 피쳐 `FamilySize`를 만들어 보도록 하겠습니다.
# (사실 새로운 피쳐를 만들어 내는 건 특성 공학쪽에서 다뤄야 하지만 일단 미리 보겠습니다.)

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다

# %%
print("Maximum size of Family: ", df_train['FamilySize'].max())
print("Minimum size of Family: ", df_train['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %%
f,ax=plt.subplots(1, 3, figsize=(40,10))
sns.countplot('FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)

sns.countplot('FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize',  y=1.02)

df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize',  y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# * Figure (1) - 가족크기가 1~11까지 있음을 볼 수 있습니다. 대부분 1명이고 그 다음으로 2, 3, 4명입니다.
# * Figure (2), (3) - 가족 크기에 따른 생존비교입니다. 가족이 4명인 경우가 가장 생존확률이 높습니다,
#   가족수가 많아질수록, (5, 6, 7, 8, 11) 생존확률이 낮아지네요.
# 가족수가 너무 작아도(1), 너무 커도(5, 6, 8, 11) 생존 확률이 작네요. 3~4명 선에서 생존확률이 높은 걸 확인할 수 있습니다.

# %% [markdown]
# ### **2.7 Fare**
#
# 해당 피쳐는 탑승 요금입니다. 연속적인 데이터이므로 한번 histogram을 그려보도록 하겠습니다.

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %%
# 특이하기도 train set 말고 test set에 Fare 피쳐에 널 값이 하나 존재하는 것을 확인할 수 있었습니다.
# 그래서 평균 값으로 해당 널값을 넣어줍니다.
df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean() # testset 에 있는 nan value 를 평균값으로 치환합니다.

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i > 0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i > 0 else 0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %% [markdown]
# log 를 취하니, 이제 비대칭성이 많이 사라진 것을 볼 수 있습니다.
# 우리는 이런 작업을 사용해 모델이 좀 더 좋은 성능을 내도록 할 수 있습니다.
# 사실 방금한 것은 **feature engineering** 에 들어가는 부분인데, 여기서 작업했습니다.
# 모델을 학습시키기 위해, 그리고 그 모델의 성능을 높이기 위해 feature 들에 여러 조작을 가하거나,
# 새로운 feature를 추가하는 것을 feature engineering 이라고 하는데,
# 우리는 다음 챕터에 그것을 살펴볼 것입니다.

# %% [markdown]
# ### **2.8 Cabin**
#
# 이 feature 는 NaN 이 대략 80% 이므로, 생존에 영향을 미칠 중요한 정보를 얻어내기가 쉽지는 않습니다.
# 그러므로 우리가 세우려는 모델에 포함시키지 않도록 하겠습니다.

# %%
### Cabin 피쳐의 Null 비율 계산
df_train["Cabin"].isnull().sum() / df_train.shape[0]
# Out:
# 0.7710437710437711

# %%
df_train.head()[["PassengerId", "Cabin"]]
# Out:
#    PassengerId Cabin
# 0            1   NaN
# 1            2   C85
# 2            3   NaN
# 3            4  C123
# 4            5   NaN

# %% [markdown]
# ### **2.9 Ticket**
#
# 이 feature 는 NaN 은 없습니다. 일단 string data 이므로 우리가 어떤 작업들을 해주어야
# 실제 모델에 사용할 수 있는데, 이를 위해선 사실 아이디어가 필요합니다.

# %%
df_train['Ticket'].value_counts()
# Out:
# 1601                  7
# CA. 2343              7
# 347082                7
# CA 2144               6
# 3101295               6
# 347088                6
# 382652                5
# S.O.C. 14879          5
# W./C. 6608            4
# 4133                  4
# 113760                4
# 113781                4
# PC 17757              4
# LINE                  4
# 347077                4
# 2666                  4
# 17421                 4
# 349909                4
# 19950                 4
# 230080                3
# PC 17572              3
# 24160                 3
# 248727                3
# F.C.C. 13529          3
# 110413                3
# 13502                 3
# 345773                3
# PC 17760              3
# 35273                 3
# SC/Paris 2123         3
#                      ..
# 382651                1
# 236853                1
# SOTON/O.Q. 3101305    1
# 243880                1
# 2689                  1
# C.A. 33595            1
# 347466                1
# STON/O 2. 3101292     1
# 349214                1
# C.A./SOTON 34068      1
# 113050                1
# 350034                1
# STON/O2. 3101271      1
# 347064                1
# 349252                1
# 2697                  1
# 28220                 1
# SOTON/OQ 392086       1
# PC 17601              1
# 5727                  1
# 65304                 1
# 349225                1
# STON/O 2. 3101273     1
# 2677                  1
# 14313                 1
# 244373                1
# 11753                 1
# A/5. 3337             1
# PC 17612              1
# 345783                1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# 보시다시피, ticket number 는 매우 다양합니다.
# 우리는 여기서 어떤 특징을 이끌어내서 생존과 연결시킬 수 있을까요?
# 한번 생각을 해보시고 새로운 Feature를 만들어 모델의 성능을 끌어올리는 것도
# 재밌는 데이터 분석 과정 중 하나니 힘내서 생각하시고 즐겨보시길 바랍니다!!

# %% [markdown]
# ## 3. 특성 공학 (Feature Engineering)
# ---
# 본격적인 feature engineering 을 시작해보겠습니다.
#
# ***"Garbage In, Garbage out"* **
#
# 특성 공학을 통해 다양 피쳐를 만드시고, 정제하실 텐데
# 자기가 생각한 가정이 항상 타당한지 생각하시고 진행해 주시길 바랍니다!
# 아무리 좋은 모델도, 안좋은 데이터가 들어오면 안좋은 결과로 나오기 마련이니까요.
#
# 가장 먼저, dataset 에 존재하는 null data를 채우려고 합니다.
# 아무 숫자로 채울 수는 없고, null data 를 포함하는 feature 의 statistics 를 참고하거나,
# 다른 아이디어를 짜내어 채울 수 있습니다.
#
# null data 를 어떻게 채우느냐에 따라 모델의 성능이 좌지우지될 수 있기 때문에, 신경써줘야할 부분입니다.
#
# 특히, Feature engineering 은 실제 모델의 학습에 쓰려고 하는 것이므로,
# **train 뿐만 아니라 test 도 똑같이 적용**해주어야 합니다. 잊지맙시다.

# %% [markdown]
# ### **3.1 Fill Null**
#
# ### 3.1.1 Fill Null in Age using title

# %%
df_train["Age"].isnull().sum()
# Out:
# 177

# %% [markdown]
# Age 에는 null data가 177개나 있습니다. 이를 채울 수 있는 여러 아이디어가 있을 것인데,
# 여기서 우리는 **title + statistics** 를 사용해 보겠습니다.
#
# 영어에서는 Miss, Mrr, Mrs 같은 title이 존재합니다.
# 각 탑승객의 이름에는 꼭 이런 title 이 들어가게 되는데 이를 사용해보겠습니다.
#
# pandas series 에는 data 를 string 으로 바꿔주는 `str` method,
# 거기에 정규표현식을 적용하게 해주는 `extract` method가 있습니다.
# 이를 사용하여 title 을 쉽게 추출할 수 있습니다. title을 `Initial` column에 저장하겠습니다

# %%
df_train['Initial']= df_train.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
df_test['Initial']= df_test.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %% [markdown]
# pandas 의 crosstab 을 이용하여 우리가 추출한 Initial 과 Sex 간의 count 를 살펴봅시다.
# 혹시나 잘 못 이름이 적혀져 있거나 성별을 잘 못 분류 했을 수도 있으니깐요?

# %%
pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_16471332_ffde_11eb_912b_0242ac130202row0_col0 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col1 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col2 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col3 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col4 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col5 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col6 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col7 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col8 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col9 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col10 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col11 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col12 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col13 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col14 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col15 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row0_col16 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col0 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col1 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col2 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col3 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col4 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col5 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col6 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col7 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col8 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col9 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col10 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col11 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col12 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col13 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col14 {
#             background-color:  #ffff66;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col15 {
#             background-color:  #008066;
#         }    #T_16471332_ffde_11eb_912b_0242ac130202row1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_16471332_ffde_11eb_912b_0242ac130202" >
# <thead>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Countess</th>
#         <th class="col_heading level0 col3" >Don</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_16471332_ffde_11eb_912b_0242ac130202level0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col0" class="data row0 col0" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col1" class="data row0 col1" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col2" class="data row0 col2" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col3" class="data row0 col3" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col4" class="data row0 col4" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col5" class="data row0 col5" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col6" class="data row0 col6" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col7" class="data row0 col7" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col8" class="data row0 col8" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col9" class="data row0 col9" >182</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col10" class="data row0 col10" >2</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col11" class="data row0 col11" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col12" class="data row0 col12" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col13" class="data row0 col13" >125</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col14" class="data row0 col14" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col15" class="data row0 col15" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_16471332_ffde_11eb_912b_0242ac130202level0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_col0" class="data row1 col0" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_col1" class="data row1 col1" >2</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_col2" class="data row1 col2" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_col3" class="data row1 col3" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_col4" class="data row1 col4" >6</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_col5" class="data row1 col5" >1</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_col6" class="data row1 col6" >0</td>
#         <td id="T_16471332_ffde_11eb_912b_0242ac130202row1_c

# %%
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

df_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

# %%
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived     ...          Fare  FamilySize
# Initial                            ...
# Master    414.975000  0.575000     ...      3.340710    4.675000
# Miss      411.741935  0.704301     ...      3.123713    2.236559
# Mr        455.880907  0.162571     ...      2.651507    1.444234
# Mrs       456.393701  0.795276     ...      3.443751    2.511811
# Other     564.444444  0.111111     ...      2.641605    1.222222
#
# [5 rows x 8 columns]

# %%
df_train.groupby('Initial')['Survived'].mean().plot.bar()

# %% [markdown]
# 이제 본격적으로 Null 을 채울 것입니다. null data 를 채우는 방법은 정말 많이 존재합니다.
# statistics 를 활용하는 방법도 있고, null data 가 없는 데이터를
# 기반으로 새로운 머신러닝 알고리즘을 만들어 예측해서 채워넣는 방식도 있습니다.
# *(딥러닝에서 디노이징 오토인코더 라는 것이 있습니다!)*
#
# 여기서는 statistics 를 활용하는 방법을 사용할 것입니다.
# 여기서 statistics 는 train data 의 것을 의미합니다.
# 우리는 언제나 test 를 unseen 으로 둔 상태로 놔둬야 하며,
# train 에서 얻은 statistics 를 기반으로 test 의 null data 를 채워줘야 합니다.

# %%
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived     ...          Fare  FamilySize
# Initial                            ...
# Master    414.975000  0.575000     ...      3.340710    4.675000
# Miss      411.741935  0.704301     ...      3.123713    2.236559
# Mr        455.880907  0.162571     ...      2.651507    1.444234
# Mrs       456.393701  0.795276     ...      3.443751    2.511811
# Other     564.444444  0.111111     ...      2.641605    1.222222
#
# [5 rows x 8 columns]

# %% [markdown]
# 저희는 각 initial 그룹별 Age 평균 값을 사용해서 채워 넣도록 하겠습니다.

# %%
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'),'Age'] = 33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'),'Age'] = 36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'),'Age'] = 5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'),'Age'] = 22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'),'Age'] = 46

df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mr'),'Age'] = 33
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mrs'),'Age'] = 36
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Master'),'Age'] = 5
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Miss'),'Age'] = 22
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Other'),'Age'] = 46

# %%
df_train.isnull().sum()[df_train.isnull().sum() > 0]
# Out:
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_test.isnull().sum()[df_test.isnull().sum() > 0]
# Out:
# Cabin    327
# dtype: int64

# %% [markdown]
# train & test 셋에 Age의 널처리가 완전히 끝난 것을 보실 수 있습니다.
#
# 여기선 간단하게 Null을 채웠지만, 좀 더 다양한 방법을 쓴 예시들이 다른 커널에 존재합니다
# https://www.kaggle.com/yassineghouzam/titanic-top-4-with-ensemble-modeling 보시면서 공부해보세요!

# %% [markdown]
# ### 3.1.2 Fill Null in Embarked

# %%
print('Embarked has ', sum(df_train['Embarked'].isnull()), ' Null values')
# Out:
# Embarked has  2  Null values

# %% [markdown]
# Embarked 는 Null value 가 2개이고, S 에서 가장 많은 탑승객이 있었으므로,
# 간단하게 Null 을 S로 채우겠습니다.
#
# dataframe 의 `fillna` method 를 이용하면 쉽게 채울 수 있습니다.
# 여기서 inplace=True 로 하면 df_train 에 fillna 를 실제로 적용하게 됩니다.

# %%
df_train['Embarked'].fillna('S', inplace=True)

# %%
df_train.isnull().sum()[df_train.isnull().sum() > 0]
# Out:
# Cabin    687
# dtype: int64

# %% [markdown]
# ### **3.2. Change Age(continuous to categorical)**
#
# Age 는 현재 continuous feature 입니다. 이대로 써도 모델을 세울 수 있지만,
# Age 를 몇개의 group 으로 나누어 category 화 시켜줄 수 도 있습니다.
#
# continuous 를 categorical 로 바꾸면 자칫 **information loss** 가 생길 수도 있습니다만,
# 본 튜토리얼에서는 다양한 방법을 소개하는 것이 목적이므로 진행하도록 하겠습니다.
#
# 방법은 여러가지가 있습니다.
# dataframe 의 indexing 방법인 loc 를 사용하여 직접해줄 수 있고,
# 아니면 apply 를 사용해 함수를 넣어줄 수 있습니다.
#
# loc 예제는 위의 age mean 값을 채워 줬을 때 사용해 봤으므로,
# 여기에선 apply를 사용해 보도록 하겠습니다.

# %%
def category_age(x):
    if x < 10:
        return 0
    elif x < 20:
        return 1
    elif x < 30:
        return 2
    elif x < 40:
        return 3
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    else:
        return 7    
    
df_train['Age_cat'] = df_train['Age'].apply(category_age)
df_test['Age_cat'] = df_test['Age'].apply(category_age)

# %%
df_train.groupby(['Age_cat'])['PassengerId'].count()
# Out:
# Age_cat
# 0     66
# 1    102
# 2    256
# 3    304
# 4     89
# 5     48
# 6     19
# 7      7
# Name: PassengerId, dtype: int64

# %% [markdown]
# 이제 파생 피쳐를 만들었으므로 원래 컬럼 Age 를 제거하는게 맞겠지만,
# 저희는 상관 관계가 높아도 모델의 설명력(성능)에 도움이 될 수 있으니
# 남겨 보도록 하겠습니다.

# %% [markdown]
# ### **3.3 Change Initial, Embarked and Sex (string to numerical)**
#
# 현재 Initial 은 Mr, Mrs, Miss, Master, Other 총 5개로 이루어져 있습니다.
# 이런 카테고리로 표현되어져 있는 데이터를 모델에 인풋으로 넣어줄 때
# 우리가 해야할 것은 먼저 **컴퓨터가 인식할 수 있도록 수치화** 시켜야 합니다.
#
# `map` method 를 가지고 간단히 할 수 있습니다.
# 사전 순서대로 정리하여 mapping 하겠습니다

# %%
df_train['Initial'] = df_train['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})
df_test['Initial'] = df_test['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})

# %% [markdown]
# 마찬가지 `Embarked`와 `Sex` 피쳐도 string이라 같은 과정을 거치겠습니다.

# %%
df_train['Embarked'] = df_train['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
df_test['Embarked'] = df_test['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
df_train['Embarked'].isnull().any() , df_train['Embarked'].dtypes
# Out:
# (False, dtype('int64'))

# %% [markdown]
# 널이 없고, int형으로 잘 바뀐 것으로 보아 잘 변환 되었음을 확인할 수 있습니다.
# 마찬가지 `sex`에도 적용합니다.

# %%
df_train['Sex'] = df_train['Sex'].map({'female': 0, 'male': 1})
df_test['Sex'] = df_test['Sex'].map({'female': 0, 'male': 1})

# %% [markdown]
# 여지껏 고생하셨습니다!! 엄청 많은걸 하셨어요!!
#
# 이제 각 feature 간의 상관관계를 한번 보려고 합니다.
# 두 변수간의 Pearson correlation 을 구하면 (-1, 1) 사이의 값을 얻을 수 있습니다.
# * -1로 갈수록 음의 상관관계,
# * 1로 갈수록 양의 상관관계를 의미하며
# * 0은 상관관계가 없다는 것을 의미합니다.
#
# 따로 수식은 적지 않도록 하겠습니다. 검색만 하셔도 수식은 많이 나오니
# 궁금하시면 공부해보시걸 추천합니다!

# %%
heatmap_data = df_train[['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked', 'FamilySize', 'Initial', 'Age_cat', 'Age']] 

colormap = plt.cm.RdBu
plt.figure(figsize=(14, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

del heatmap_data

# %% [markdown]
# 우리가 EDA에서 살펴봤듯이,
# Sex 와 Pclass 가 Survived 에 상관관계가 어느 정도 있음을 볼 수 있습니다.
#
# 생각보다 fare 와 Embarked 도 상관관계가 있음을 볼 수 있습니다.
#
# 또한 우리가 여기서 얻을 수 있는 정보는
# 서로 강한 상관관계를 가지는 feature들이 없다는 것입니다.
# (Age와 Age_cat 제외..)
# 이것은 우리가 모델을 학습시킬 때, 불필요한 feature 가 없다는 것을 의미합니다.
# **1 또는 -1 의 상관관계를 가진 feature A, B 가 있다면, 우리가 얻을 수 있는 정보는 사실 하나일 거니까요.**
#
# 이제 실제로 모델을 학습시키기 앞서서 data preprocessing (전처리)을 진행해보겠습니다.
# 거의 다 와갑니다 힙냅시다!

# %% [markdown]
# ### **3.4 One-hot encoding on Initial and Embarked**
#
# 수치화시킨 카테고리 데이터를 그대로 넣어도 되지만,
# 모델의 성능을 높이기 위해 one-hot encoding을 해줄 수 있습니다.
#
# 수치화는 간단히 Master == 0, Miss == 1, Mr == 2, Mrs == 3, Other == 4 로 매핑해주는 것을 말합니다.
#
# One-hot encoding 은 위 카테고리를 아래와 같이 (0, 1) 로 이루어진 5차원의 벡터로 나타내는 것을 말합니다.
#
# |        | Initial_Master | Initial_Miss | Initial_Mr | Initial_Mrs | Initial_Other |
# |--------|----------------|--------------|------------|-------------|---------------|
# | Master | 1              | 0            | 0          | 0           | 0             |
# | Miss   | 0              | 1            | 0          | 0           | 0             |
# | Mr     | 0              | 0            | 1          | 0           | 0             |
# | Mrs    | 0              | 0            | 0          | 1           | 0             |
# | Other  | 0              | 0            | 0          | 0           | 1             |

# %% [markdown]
# 이렇게 하게 되면 **각 클래스간 연관성을 Orthogonal(직교, 동일하게)** 만들 수 있습니다.
# 그래서 각 클래스 관의 상관 관계가 없어집니다.
#
# > **More?**:
# >그냥 수치화 했을 경우 Master랑 Miss가 가까운 관계, Mrs와 Other이 가까운 관계로 해석될 수 있습니다.
# >더 자세한 사항은 Label Encoding vs One-hot Encoding 으로 검색하시면 더 자세하게 알아 보실 수 있습니다.
#
# 위와 같은 작업을 직접 코딩할 수도 있지만, pandas 의 `get_dummies` 를 사용하여 쉽게 해결 할 수 있습니다.
# 총 5개의 카테고리니, one-hot encoding 을 하고 나면 새로운 5개의 column 이 생겨납니다.
# Initial 을 prefix로 두어서 구분이 쉽게 만들어 줍니다 .

# %%
df_train = pd.get_dummies(df_train, columns=['Initial'], prefix='Initial')
df_test = pd.get_dummies(df_test, columns=['Initial'], prefix='Initial')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass    ...     Initial_2  Initial_3  Initial_4
# 0            1         0       3    ...             1          0          0
# 1            2         1       1    ...             0          1          0
# 2            3         1       3    ...             0          0          0
# 3            4         1       1    ...             0          1          0
# 4            5         0       3    ...             1          0          0
#
# [5 rows x 19 columns]

# %% [markdown]
# Embarked 에도 적용하겠습니다. Initial 때와 마찬가지로 one-hot encoding 을 사용해 표현하겠습니다.

# %%
df_train = pd.get_dummies(df_train, columns=['Embarked'], prefix='Embarked')
df_test = pd.get_dummies(df_test, columns=['Embarked'], prefix='Embarked')

# %% [markdown]
# 아주 쉽게 one-hot encoding 을 적용했습니다.
# 다른 패키지로도 원핫 인코딩을 적용 시킬 수 있지만, 여기에선 다루지 않겠습니다.
#
# > **Tips**:
# > 가끔 category 가 100개가 넘어가는 경우가 있습니다.
# 이때 one-hot encoding을 사용하면 column이 100개가 생겨,
# 학습시 매우 버거울 경우가 있습니다. (**차원의 저주**라고 부르기도 합니다.)
# >
# >이런 경우는 다른 방법을 사용하기도 하는데, 이는 나중에 다른 컴피티션 참가하시면
# **차원의 저주** 키워드로 해결 방법을 모색하시길 바랍니다!

# %% [markdown]
# ### **3.5 Drop columns**
#
# 마지막으로 필요없는 피쳐를 없애버릴 차례입니다!

# %%
df_train.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name',  'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass  Sex     ...      Embarked_0  Embarked_1  Embarked_2
# 0         0       3    1     ...               0           0           1
# 1         1       1    0     ...               1           0           0
# 2         1       3    0     ...               0           0           1
# 3         1       1    0     ...               0           0           1
# 4         0       3    1     ...               0           0           1
#
# [5 rows x 15 columns]

# %%
df_train.dtypes
# Out:
# Survived        int64
# Pclass          int64
# Sex             int64
# Age           float64
# Fare          float64
# FamilySize      int64
# Age_cat         int64
# Initial_0       uint8
# Initial_1       uint8
# Initial_2       uint8
# Initial_3       uint8
# Initial_4       uint8
# Embarked_0      uint8
# Embarked_1      uint8
# Embarked_2      uint8
# dtype: object

# %%
df_test.head()
# Out:
#    Pclass  Sex   Age     ...      Embarked_0  Embarked_1  Embarked_2
# 0       3    1  34.5     ...               0           1           0
# 1       3    0  47.0     ...               0           0           1
# 2       2    1  62.0     ...               0           1           0
# 3       3    1  27.0     ...               0           0           1
# 4       3    0  22.0     ...               0           0           1
#
# [5 rows x 14 columns]

# %%
df_test.dtypes
# Out:
# Pclass          int64
# Sex             int64
# Age           float64
# Fare          float64
# FamilySize      int64
# Age_cat         int64
# Initial_0       uint8
# Initial_1       uint8
# Initial_2       uint8
# Initial_3       uint8
# Initial_4       uint8
# Embarked_0      uint8
# Embarked_1      uint8
# Embarked_2      uint8
# dtype: object

# %% [markdown]
# 보시다시피, train 의 Survived feature(target class)를 빼면
# train, test 둘다 같은 columns 를 가진 걸 확인할 수 있습니다.

# %% [markdown]
# ## 4. 모델 개발 및 학습
# ---
#
# Sklearn 은 머신러닝을 위한 라이브러리
# feature engineering, preprocessing, 지도 학습 알고리즘, 비지도 학습 알고리즘,  모델 평가, 파이프라인 등...
#
# 지금 타이타닉 문제는 target class(survived)가 있으며, target class 는 0, 1로 이루어져 있으므로(binary)
# **binary classfication** 문제입니다.
#
# 우리가 지금 가지고 있는 train set 의 survived를 제외한 input 을 가지고
# 모델을 최적화시켜서 각 샘플(탑승객)의 생존유무를 판단하는 모델을 만들어 냅니다.
# 그 후 모델이 학습하지 않았던 test set 을 input 으로 주어서 test set 의 각 샘플(탑승객)의 생존 유무를 예측해봅니다.

# %%
#importing all the required ML packages
from sklearn.ensemble import RandomForestClassifier # randomforestclassfier 
from sklearn import metrics # 모델의 평가를 위해서 씁니다
from sklearn.model_selection import train_test_split # traning set을 쉽게 나눠주는 함수입니다.

# %% [markdown]
# ### **4.1 Preparation - Split dataset into train, valid(dev), test set**
#
# train data set과 target label(Survived)를 분리
# `drop` 을 사용

# %%
X_train = df_train.drop('Survived', axis=1).values
target_label = df_train['Survived'].values
X_test = df_test.values

# %%
X_train.shape, X_test.shape
# Out:
# ((891, 14), (418, 14))

# %% [markdown]
# 실제 좋은 모델을 만들기 위해서 validation set을 따로 만들어 모델 평가
#
# train_test_split 을 사용하여 쉽게 train 셋에서 train과 validation을 분리
#
# > **More?**
# > Overfitting(과적합) 이슈를 나중에 공부해보시면 왜 Validation을 나누는지 이해할 수 있을 것입니다!

# %%
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.2, random_state=2018)

# %%
y_tr.shape, y_vld.shape
# Out:
# ((712,), (179,))

# %% [markdown]
# sklearn 에서는 여러 머신러닝 알고리즘을 지원해줍니다.
#
# 본 튜토리얼에서는 랜덤포레스트 모델을 사용하도록 하겠습니다.
# 랜덤포레스트는 결정트리기반 모델이며, 여러 결정 트리들을 앙상블한 모델입니다.
#
# 각 머신러닝 알고리즘에는 여러 파라미터들이 있습니다.
# 랜덤포레스트분류기도 n_estimators, max_features, max_depth, min_samples_split, min_samples_leaf 등 여러 파라미터들이 존재합니다.
# 이것들이 어떻게 세팅되냐에 따라 같은 데이터셋이라 하더라도 모델의 성능이 달라집니다.
#
# **파라미터 튜닝**은 시간, 경험, 알고리즘에 대한 이해 등이 필요합니다.
#
# 기본 default 세팅으로 진행하겠습니다.
#
# 모델 객체를 만들고, `fit` 메소드로 학습시킵니다.
# 그런 후 valid set input 을 넣어주어 예측값(X_vld sample(탑승객)의 생존여부)를 얻습니다.

# %% [markdown]
# ### **4.2 Model generation and prediction**
#
# 이제 랜덤포레스트 모델을 생성하고 학습해 보겠습니다.

# %%
model = RandomForestClassifier()
model.fit(X_tr, y_tr)
prediction = model.predict(X_vld)

# %%
print('총 {}명 중 {:.2f}% 정확도로 생존을 맞춤'.format(y_vld.shape[0], 100 * metrics.accuracy_score(prediction, y_vld)))
# Out:
# 총 179명 중 81.01% 정확도로 생존을 맞춤

# %% [markdown]
# 아무런 파라미터 튜닝도 하지 않았는데 81% 의 정확도

# %% [markdown]
# 학습된 모델은 feature importance 를 가지게 되는데,
# 우리는 이것을 확인하여 지금 만든 모델이 어떤 feature 에 영향을 많이 받았는 지 확인할 수 있습니다.
#
# 학습된 모델은 기본적으로 feature importances 를 가지고 있어서 쉽게 그 수치를 얻을 수 있습니다.
# pandas series 를 이용하면 쉽게 sorting 을 하여 그래프를 그릴 수 있습니다.

# %%
from pandas import Series

feature_importance = model.feature_importances_
Series_feat_imp = Series(feature_importance, index=df_test.columns)

# %%
plt.figure(figsize=(8, 8))
Series_feat_imp.sort_values(ascending=True).plot.barh()
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ## 4.B keras를 사용한 NN 모델 개발

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from keras.optimizers import Adam, SGD

# %%
nn_model = Sequential()
nn_model.add(Dense(32,activation='relu',input_shape=(14,)))
nn_model.add(Dropout(0.2))
nn_model.add(Dense(64,activation='relu'))
nn_model.add(Dropout(0.2))
nn_model.add(Dense(32,activation='relu'))
nn_model.add(Dropout(0.2))
nn_model.add(Dense(1,activation='sigmoid'))

Loss = 'binary_crossentropy'
nn_model.compile(loss=Loss,optimizer=Adam(),metrics=['accuracy'])
nn_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,705
# Trainable params: 4,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = nn_model.fit(X_tr,y_tr,
                    batch_size=64,
                    epochs=500,
                    validation_data=(X_vld, y_vld),
                    verbose=1)
# Out:
# Train on 712 samples, validate on 179 samples
# Epoch 1/500
# 712/712 [==============================] - 0s 658us/step - loss: 1.1743 - acc: 0.5772 - val_loss: 0.6682 - val_acc: 0.6089
# Epoch 2/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.9560 - acc: 0.5112 - val_loss: 0.6311 - val_acc: 0.6425
# Epoch 3/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.8364 - acc: 0.5463 - val_loss: 0.6318 - val_acc: 0.6480
# Epoch 4/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.7538 - acc: 0.5730 - val_loss: 0.6396 - val_acc: 0.6760
# Epoch 5/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.7591 - acc: 0.5379 - val_loss: 0.6465 - val_acc: 0.6927
# Epoch 6/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.7518 - acc: 0.5632 - val_loss: 0.6423 - val_acc: 0.6648
# Epoch 7/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.7541 - acc: 0.5323 - val_loss: 0.6442 - val_acc: 0.6648
# Epoch 8/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.7254 - acc: 0.5801 - val_loss: 0.6499 - val_acc: 0.6872
# Epoch 9/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.7172 - acc: 0.5478 - val_loss: 0.6429 - val_acc: 0.6480
# Epoch 10/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.6959 - acc: 0.5885 - val_loss: 0.6380 - val_acc: 0.6480
# Epoch 11/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.7001 - acc: 0.5941 - val_loss: 0.6536 - val_acc: 0.6872
# Epoch 12/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.6809 - acc: 0.6138 - val_loss: 0.6469 - val_acc: 0.6872
# Epoch 13/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.6756 - acc: 0.6081 - val_loss: 0.6264 - val_acc: 0.6592
# Epoch 14/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.6636 - acc: 0.6292 - val_loss: 0.6385 - val_acc: 0.6872
# Epoch 15/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.6731 - acc: 0.6039 - val_loss: 0.6355 - val_acc: 0.6816
# Epoch 16/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.6756 - acc: 0.6011 - val_loss: 0.6343 - val_acc: 0.6760
# Epoch 17/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.6704 - acc: 0.6152 - val_loss: 0.6286 - val_acc: 0.6704
# Epoch 18/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.6543 - acc: 0.6236 - val_loss: 0.6166 - val_acc: 0.6592
# Epoch 19/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.6622 - acc: 0.6039 - val_loss: 0.6154 - val_acc: 0.6704
# Epoch 20/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.6287 - acc: 0.6615 - val_loss: 0.6078 - val_acc: 0.6760
# Epoch 21/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.6302 - acc: 0.6559 - val_loss: 0.6027 - val_acc: 0.6816
# Epoch 22/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.6254 - acc: 0.6629 - val_loss: 0.6111 - val_acc: 0.7430
# Epoch 23/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.6451 - acc: 0.6447 - val_loss: 0.5976 - val_acc: 0.6872
# Epoch 24/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.6343 - acc: 0.6573 - val_loss: 0.5898 - val_acc: 0.6927
# Epoch 25/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.6160 - acc: 0.6868 - val_loss: 0.5829 - val_acc: 0.7598
# Epoch 26/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.6105 - acc: 0.6756 - val_loss: 0.5686 - val_acc: 0.7709
# Epoch 27/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.5929 - acc: 0.6784 - val_loss: 0.5461 - val_acc: 0.7821
# Epoch 28/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.5931 - acc: 0.6994 - val_loss: 0.5408 - val_acc: 0.7654
# Epoch 29/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.5787 - acc: 0.6938 - val_loss: 0.5277 - val_acc: 0.7765
# Epoch 30/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.5697 - acc: 0.7233 - val_loss: 0.5199 - val_acc: 0.7821
# Epoch 31/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.5614 - acc: 0.7374 - val_loss: 0.5086 - val_acc: 0.7989
# Epoch 32/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.5548 - acc: 0.7275 - val_loss: 0.4911 - val_acc: 0.7877
# Epoch 33/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.5460 - acc: 0.7500 - val_loss: 0.4891 - val_acc: 0.7989
# Epoch 34/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.5496 - acc: 0.7261 - val_loss: 0.4848 - val_acc: 0.7933
# Epoch 35/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.5302 - acc: 0.7683 - val_loss: 0.4641 - val_acc: 0.8101
# Epoch 36/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.5153 - acc: 0.7598 - val_loss: 0.4644 - val_acc: 0.7877
# Epoch 37/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.5455 - acc: 0.7486 - val_loss: 0.4604 - val_acc: 0.7877
# Epoch 38/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.5125 - acc: 0.7669 - val_loss: 0.4488 - val_acc: 0.8268
# Epoch 39/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.5106 - acc: 0.7697 - val_loss: 0.4514 - val_acc: 0.8101
# Epoch 40/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.5018 - acc: 0.7725 - val_loss: 0.4316 - val_acc: 0.8268
# Epoch 41/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4907 - acc: 0.7809 - val_loss: 0.4284 - val_acc: 0.8324
# Epoch 42/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.5132 - acc: 0.7654 - val_loss: 0.4284 - val_acc: 0.8212
# Epoch 43/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.5034 - acc: 0.7753 - val_loss: 0.4218 - val_acc: 0.8212
# Epoch 44/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4923 - acc: 0.7851 - val_loss: 0.4274 - val_acc: 0.8268
# Epoch 45/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4700 - acc: 0.7963 - val_loss: 0.4118 - val_acc: 0.8436
# Epoch 46/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4825 - acc: 0.7865 - val_loss: 0.4139 - val_acc: 0.8324
# Epoch 47/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4708 - acc: 0.7865 - val_loss: 0.4093 - val_acc: 0.8324
# Epoch 48/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4693 - acc: 0.8104 - val_loss: 0.4029 - val_acc: 0.8324
# Epoch 49/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.4885 - acc: 0.7865 - val_loss: 0.4026 - val_acc: 0.8324
# Epoch 50/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4800 - acc: 0.7963 - val_loss: 0.4011 - val_acc: 0.8492
# Epoch 51/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4865 - acc: 0.7809 - val_loss: 0.4119 - val_acc: 0.8324
# Epoch 52/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4737 - acc: 0.7949 - val_loss: 0.4085 - val_acc: 0.8492
# Epoch 53/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4609 - acc: 0.7949 - val_loss: 0.4068 - val_acc: 0.8547
# Epoch 54/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4771 - acc: 0.7949 - val_loss: 0.4074 - val_acc: 0.8324
# Epoch 55/500
# 712/712 [==============================] - 0s 25us/step - loss: 0.4607 - acc: 0.7978 - val_loss: 0.4005 - val_acc: 0.8492
# Epoch 56/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4503 - acc: 0.8020 - val_loss: 0.4001 - val_acc: 0.8436
# Epoch 57/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4643 - acc: 0.7907 - val_loss: 0.3998 - val_acc: 0.8436
# Epoch 58/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4716 - acc: 0.7907 - val_loss: 0.4078 - val_acc: 0.8380
# Epoch 59/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4573 - acc: 0.8006 - val_loss: 0.3997 - val_acc: 0.8436
# Epoch 60/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.4525 - acc: 0.8104 - val_loss: 0.3938 - val_acc: 0.8492
# Epoch 61/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.4399 - acc: 0.8090 - val_loss: 0.3934 - val_acc: 0.8492
# Epoch 62/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4487 - acc: 0.8104 - val_loss: 0.3909 - val_acc: 0.8492
# Epoch 63/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4407 - acc: 0.8090 - val_loss: 0.3870 - val_acc: 0.8492
# Epoch 64/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4402 - acc: 0.8174 - val_loss: 0.3853 - val_acc: 0.8436
# Epoch 65/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4357 - acc: 0.8188 - val_loss: 0.3943 - val_acc: 0.8380
# Epoch 66/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4351 - acc: 0.8118 - val_loss: 0.3846 - val_acc: 0.8380
# Epoch 67/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.4450 - acc: 0.8090 - val_loss: 0.3899 - val_acc: 0.8436
# Epoch 68/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.4550 - acc: 0.8048 - val_loss: 0.3970 - val_acc: 0.8436
# Epoch 69/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.4437 - acc: 0.8146 - val_loss: 0.3907 - val_acc: 0.8436
# Epoch 70/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4415 - acc: 0.8020 - val_loss: 0.3880 - val_acc: 0.8492
# Epoch 71/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4332 - acc: 0.8146 - val_loss: 0.3847 - val_acc: 0.8436
# Epoch 72/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.4353 - acc: 0.8188 - val_loss: 0.3880 - val_acc: 0.8547
# Epoch 73/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.4207 - acc: 0.8160 - val_loss: 0.3890 - val_acc: 0.8547
# Epoch 74/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.4361 - acc: 0.8104 - val_loss: 0.3881 - val_acc: 0.8436
# Epoch 75/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.4389 - acc: 0.8146 - val_loss: 0.3875 - val_acc: 0.8436
# Epoch 76/500
# 712/712 [==============================] - 0s 42us/step - loss: 0.4331 - acc: 0.8230 - val_loss: 0.3849 - val_acc: 0.8547
# Epoch 77/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.4429 - acc: 0.8118 - val_loss: 0.3822 - val_acc: 0.8547
# Epoch 78/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4380 - acc: 0.8174 - val_loss: 0.3833 - val_acc: 0.8492
# Epoch 79/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4298 - acc: 0.8258 - val_loss: 0.3889 - val_acc: 0.8492
# Epoch 80/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4358 - acc: 0.8146 - val_loss: 0.3844 - val_acc: 0.8380
# Epoch 81/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4355 - acc: 0.8132 - val_loss: 0.3836 - val_acc: 0.8547
# Epoch 82/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.4418 - acc: 0.8076 - val_loss: 0.4092 - val_acc: 0.8492
# Epoch 83/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.4382 - acc: 0.8076 - val_loss: 0.3913 - val_acc: 0.8380
# Epoch 84/500
# 712/712 [==============================] - 0s 40us/step - loss: 0.4244 - acc: 0.8174 - val_loss: 0.3841 - val_acc: 0.8492
# Epoch 85/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4308 - acc: 0.8104 - val_loss: 0.3858 - val_acc: 0.8603
# Epoch 86/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4433 - acc: 0.8146 - val_loss: 0.3820 - val_acc: 0.8492
# Epoch 87/500
# 712/712 [==============================] - 0s 44us/step - loss: 0.4155 - acc: 0.8329 - val_loss: 0.3819 - val_acc: 0.8380
# Epoch 88/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4124 - acc: 0.8343 - val_loss: 0.3828 - val_acc: 0.8603
# Epoch 89/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.4401 - acc: 0.8174 - val_loss: 0.3837 - val_acc: 0.8603
# Epoch 90/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4276 - acc: 0.8202 - val_loss: 0.3853 - val_acc: 0.8380
# Epoch 91/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4162 - acc: 0.8258 - val_loss: 0.3861 - val_acc: 0.8436
# Epoch 92/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4085 - acc: 0.8301 - val_loss: 0.3822 - val_acc: 0.8436
# Epoch 93/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4237 - acc: 0.8258 - val_loss: 0.3821 - val_acc: 0.8492
# Epoch 94/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.4237 - acc: 0.8132 - val_loss: 0.3805 - val_acc: 0.8492
# Epoch 95/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4189 - acc: 0.8132 - val_loss: 0.3812 - val_acc: 0.8547
# Epoch 96/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4160 - acc: 0.8258 - val_loss: 0.3835 - val_acc: 0.8380
# Epoch 97/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4170 - acc: 0.8244 - val_loss: 0.3835 - val_acc: 0.8436
# Epoch 98/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4142 - acc: 0.8174 - val_loss: 0.3812 - val_acc: 0.8380
# Epoch 99/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4220 - acc: 0.8230 - val_loss: 0.3807 - val_acc: 0.8436
# Epoch 100/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.4096 - acc: 0.8272 - val_loss: 0.3830 - val_acc: 0.8436
# Epoch 101/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.4265 - acc: 0.8202 - val_loss: 0.3763 - val_acc: 0.8547
# Epoch 102/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4168 - acc: 0.8202 - val_loss: 0.3805 - val_acc: 0.8547
# Epoch 103/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4206 - acc: 0.8287 - val_loss: 0.3847 - val_acc: 0.8436
# Epoch 104/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4047 - acc: 0.8287 - val_loss: 0.3830 - val_acc: 0.8380
# Epoch 105/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4088 - acc: 0.8244 - val_loss: 0.3795 - val_acc: 0.8492
# Epoch 106/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.4051 - acc: 0.8272 - val_loss: 0.3812 - val_acc: 0.8380
# Epoch 107/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.4142 - acc: 0.8230 - val_loss: 0.3849 - val_acc: 0.8436
# Epoch 108/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4105 - acc: 0.8301 - val_loss: 0.3805 - val_acc: 0.8547
# Epoch 109/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4240 - acc: 0.8301 - val_loss: 0.3797 - val_acc: 0.8436
# Epoch 110/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4262 - acc: 0.8216 - val_loss: 0.3852 - val_acc: 0.8492
# Epoch 111/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4209 - acc: 0.8258 - val_loss: 0.3849 - val_acc: 0.8324
# Epoch 112/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.4145 - acc: 0.8287 - val_loss: 0.3796 - val_acc: 0.8492
# Epoch 113/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4047 - acc: 0.8287 - val_loss: 0.3786 - val_acc: 0.8547
# Epoch 114/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4009 - acc: 0.8301 - val_loss: 0.3803 - val_acc: 0.8492
# Epoch 115/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.4102 - acc: 0.8357 - val_loss: 0.3799 - val_acc: 0.8492
# Epoch 116/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4147 - acc: 0.8216 - val_loss: 0.3799 - val_acc: 0.8547
# Epoch 117/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.4152 - acc: 0.8174 - val_loss: 0.3836 - val_acc: 0.8492
# Epoch 118/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.4211 - acc: 0.8258 - val_loss: 0.3909 - val_acc: 0.8547
# Epoch 119/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4075 - acc: 0.8287 - val_loss: 0.3801 - val_acc: 0.8603
# Epoch 120/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4211 - acc: 0.8244 - val_loss: 0.3774 - val_acc: 0.8492
# Epoch 121/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4228 - acc: 0.8202 - val_loss: 0.3895 - val_acc: 0.8547
# Epoch 122/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.4170 - acc: 0.8216 - val_loss: 0.3813 - val_acc: 0.8492
# Epoch 123/500
# 712/712 [==============================] - 0s 22us/step - loss: 0.3946 - acc: 0.8315 - val_loss: 0.3768 - val_acc: 0.8492
# Epoch 124/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4021 - acc: 0.8258 - val_loss: 0.3768 - val_acc: 0.8436
# Epoch 125/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4096 - acc: 0.8287 - val_loss: 0.3804 - val_acc: 0.8603
# Epoch 126/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3980 - acc: 0.8315 - val_loss: 0.3776 - val_acc: 0.8603
# Epoch 127/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4111 - acc: 0.8301 - val_loss: 0.3763 - val_acc: 0.8547
# Epoch 128/500
# 712/712 [==============================] - 0s 25us/step - loss: 0.4184 - acc: 0.8371 - val_loss: 0.3747 - val_acc: 0.8603
# Epoch 129/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4052 - acc: 0.8357 - val_loss: 0.3741 - val_acc: 0.8547
# Epoch 130/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3950 - acc: 0.8455 - val_loss: 0.3770 - val_acc: 0.8436
# Epoch 131/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.4080 - acc: 0.8371 - val_loss: 0.3763 - val_acc: 0.8547
# Epoch 132/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4057 - acc: 0.8329 - val_loss: 0.3771 - val_acc: 0.8547
# Epoch 133/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.4088 - acc: 0.8329 - val_loss: 0.3783 - val_acc: 0.8547
# Epoch 134/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4008 - acc: 0.8357 - val_loss: 0.3797 - val_acc: 0.8380
# Epoch 135/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.4066 - acc: 0.8216 - val_loss: 0.3816 - val_acc: 0.8380
# Epoch 136/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4069 - acc: 0.8244 - val_loss: 0.3817 - val_acc: 0.8547
# Epoch 137/500
# 712/712 [==============================] - 0s 40us/step - loss: 0.4152 - acc: 0.8258 - val_loss: 0.3818 - val_acc: 0.8492
# Epoch 138/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3983 - acc: 0.8258 - val_loss: 0.3793 - val_acc: 0.8492
# Epoch 139/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4060 - acc: 0.8357 - val_loss: 0.3768 - val_acc: 0.8492
# Epoch 140/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.4020 - acc: 0.8413 - val_loss: 0.3814 - val_acc: 0.8547
# Epoch 141/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.4231 - acc: 0.8371 - val_loss: 0.3851 - val_acc: 0.8436
# Epoch 142/500
# 712/712 [==============================] - 0s 25us/step - loss: 0.4136 - acc: 0.8287 - val_loss: 0.3869 - val_acc: 0.8380
# Epoch 143/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4133 - acc: 0.8357 - val_loss: 0.3830 - val_acc: 0.8492
# Epoch 144/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.4035 - acc: 0.8413 - val_loss: 0.3749 - val_acc: 0.8547
# Epoch 145/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4044 - acc: 0.8315 - val_loss: 0.3773 - val_acc: 0.8603
# Epoch 146/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.4015 - acc: 0.8258 - val_loss: 0.3837 - val_acc: 0.8436
# Epoch 147/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4107 - acc: 0.8343 - val_loss: 0.3831 - val_acc: 0.8436
# Epoch 148/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.4009 - acc: 0.8329 - val_loss: 0.3795 - val_acc: 0.8547
# Epoch 149/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4087 - acc: 0.8343 - val_loss: 0.3783 - val_acc: 0.8659
# Epoch 150/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3878 - acc: 0.8441 - val_loss: 0.3784 - val_acc: 0.8603
# Epoch 151/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3949 - acc: 0.8399 - val_loss: 0.3771 - val_acc: 0.8492
# Epoch 152/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4148 - acc: 0.8287 - val_loss: 0.3761 - val_acc: 0.8547
# Epoch 153/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4031 - acc: 0.8343 - val_loss: 0.3728 - val_acc: 0.8603
# Epoch 154/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3966 - acc: 0.8357 - val_loss: 0.3729 - val_acc: 0.8603
# Epoch 155/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3845 - acc: 0.8301 - val_loss: 0.3843 - val_acc: 0.8547
# Epoch 156/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3928 - acc: 0.8272 - val_loss: 0.3810 - val_acc: 0.8492
# Epoch 157/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3905 - acc: 0.8343 - val_loss: 0.3816 - val_acc: 0.8436
# Epoch 158/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.4034 - acc: 0.8315 - val_loss: 0.3795 - val_acc: 0.8436
# Epoch 159/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4003 - acc: 0.8329 - val_loss: 0.3828 - val_acc: 0.8492
# Epoch 160/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3903 - acc: 0.8357 - val_loss: 0.3821 - val_acc: 0.8492
# Epoch 161/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.4085 - acc: 0.8315 - val_loss: 0.3827 - val_acc: 0.8547
# Epoch 162/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.4067 - acc: 0.8385 - val_loss: 0.3769 - val_acc: 0.8547
# Epoch 163/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3935 - acc: 0.8371 - val_loss: 0.3756 - val_acc: 0.8547
# Epoch 164/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.4009 - acc: 0.8301 - val_loss: 0.3779 - val_acc: 0.8492
# Epoch 165/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3945 - acc: 0.8441 - val_loss: 0.3792 - val_acc: 0.8547
# Epoch 166/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3903 - acc: 0.8469 - val_loss: 0.3824 - val_acc: 0.8492
# Epoch 167/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3956 - acc: 0.8329 - val_loss: 0.3822 - val_acc: 0.8436
# Epoch 168/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.4015 - acc: 0.8427 - val_loss: 0.3768 - val_acc: 0.8492
# Epoch 169/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4043 - acc: 0.8329 - val_loss: 0.3735 - val_acc: 0.8547
# Epoch 170/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4011 - acc: 0.8483 - val_loss: 0.3726 - val_acc: 0.8547
# Epoch 171/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3988 - acc: 0.8357 - val_loss: 0.3715 - val_acc: 0.8547
# Epoch 172/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3939 - acc: 0.8413 - val_loss: 0.3687 - val_acc: 0.8547
# Epoch 173/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3985 - acc: 0.8441 - val_loss: 0.3722 - val_acc: 0.8547
# Epoch 174/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4102 - acc: 0.8399 - val_loss: 0.3693 - val_acc: 0.8603
# Epoch 175/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.4057 - acc: 0.8399 - val_loss: 0.3734 - val_acc: 0.8547
# Epoch 176/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.3810 - acc: 0.8497 - val_loss: 0.3820 - val_acc: 0.8603
# Epoch 177/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3905 - acc: 0.8441 - val_loss: 0.3783 - val_acc: 0.8492
# Epoch 178/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3899 - acc: 0.8371 - val_loss: 0.3702 - val_acc: 0.8492
# Epoch 179/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.4035 - acc: 0.8272 - val_loss: 0.3712 - val_acc: 0.8603
# Epoch 180/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3920 - acc: 0.8371 - val_loss: 0.3754 - val_acc: 0.8492
# Epoch 181/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3915 - acc: 0.8511 - val_loss: 0.3708 - val_acc: 0.8492
# Epoch 182/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3986 - acc: 0.8455 - val_loss: 0.3675 - val_acc: 0.8603
# Epoch 183/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3961 - acc: 0.8357 - val_loss: 0.3768 - val_acc: 0.8603
# Epoch 184/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3942 - acc: 0.8399 - val_loss: 0.3740 - val_acc: 0.8547
# Epoch 185/500
# 712/712 [==============================] - ETA: 0s - loss: 0.4453 - acc: 0.812 - 0s 37us/step - loss: 0.4012 - acc: 0.8371 - val_loss: 0.3806 - val_acc: 0.8547
# Epoch 186/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3977 - acc: 0.8427 - val_loss: 0.3799 - val_acc: 0.8492
# Epoch 187/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3988 - acc: 0.8329 - val_loss: 0.3768 - val_acc: 0.8547
# Epoch 188/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3890 - acc: 0.8455 - val_loss: 0.3724 - val_acc: 0.8492
# Epoch 189/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3836 - acc: 0.8427 - val_loss: 0.3773 - val_acc: 0.8547
# Epoch 190/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3995 - acc: 0.8357 - val_loss: 0.3792 - val_acc: 0.8436
# Epoch 191/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3956 - acc: 0.8343 - val_loss: 0.3776 - val_acc: 0.8547
# Epoch 192/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3854 - acc: 0.8413 - val_loss: 0.3827 - val_acc: 0.8547
# Epoch 193/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3894 - acc: 0.8315 - val_loss: 0.3756 - val_acc: 0.8436
# Epoch 194/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3930 - acc: 0.8385 - val_loss: 0.3803 - val_acc: 0.8547
# Epoch 195/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3887 - acc: 0.8399 - val_loss: 0.3737 - val_acc: 0.8603
# Epoch 196/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3866 - acc: 0.8469 - val_loss: 0.3742 - val_acc: 0.8603
# Epoch 197/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3861 - acc: 0.8385 - val_loss: 0.3801 - val_acc: 0.8492
# Epoch 198/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3842 - acc: 0.8399 - val_loss: 0.3788 - val_acc: 0.8547
# Epoch 199/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3886 - acc: 0.8427 - val_loss: 0.3716 - val_acc: 0.8547
# Epoch 200/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3956 - acc: 0.8483 - val_loss: 0.3737 - val_acc: 0.8603
# Epoch 201/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.4006 - acc: 0.8385 - val_loss: 0.3759 - val_acc: 0.8603
# Epoch 202/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3765 - acc: 0.8441 - val_loss: 0.3712 - val_acc: 0.8547
# Epoch 203/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3903 - acc: 0.8371 - val_loss: 0.3703 - val_acc: 0.8603
# Epoch 204/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3685 - acc: 0.8399 - val_loss: 0.3740 - val_acc: 0.8603
# Epoch 205/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3832 - acc: 0.8483 - val_loss: 0.3752 - val_acc: 0.8603
# Epoch 206/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3976 - acc: 0.8357 - val_loss: 0.3751 - val_acc: 0.8547
# Epoch 207/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3913 - acc: 0.8371 - val_loss: 0.3778 - val_acc: 0.8547
# Epoch 208/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3864 - acc: 0.8455 - val_loss: 0.3811 - val_acc: 0.8603
# Epoch 209/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3952 - acc: 0.8329 - val_loss: 0.3705 - val_acc: 0.8603
# Epoch 210/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3949 - acc: 0.8413 - val_loss: 0.3776 - val_acc: 0.8547
# Epoch 211/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3758 - acc: 0.8539 - val_loss: 0.3778 - val_acc: 0.8547
# Epoch 212/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3928 - acc: 0.8343 - val_loss: 0.3807 - val_acc: 0.8436
# Epoch 213/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3841 - acc: 0.8483 - val_loss: 0.3733 - val_acc: 0.8436
# Epoch 214/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3834 - acc: 0.8427 - val_loss: 0.3783 - val_acc: 0.8492
# Epoch 215/500
# 712/712 [==============================] - 0s 40us/step - loss: 0.3941 - acc: 0.8343 - val_loss: 0.3928 - val_acc: 0.8436
# Epoch 216/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3810 - acc: 0.8525 - val_loss: 0.3765 - val_acc: 0.8547
# Epoch 217/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3965 - acc: 0.8385 - val_loss: 0.3767 - val_acc: 0.8492
# Epoch 218/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3783 - acc: 0.8357 - val_loss: 0.3740 - val_acc: 0.8492
# Epoch 219/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3886 - acc: 0.8399 - val_loss: 0.3702 - val_acc: 0.8603
# Epoch 220/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3788 - acc: 0.8497 - val_loss: 0.3818 - val_acc: 0.8547
# Epoch 221/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3840 - acc: 0.8497 - val_loss: 0.3778 - val_acc: 0.8603
# Epoch 222/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3879 - acc: 0.8343 - val_loss: 0.3772 - val_acc: 0.8659
# Epoch 223/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3804 - acc: 0.8413 - val_loss: 0.3773 - val_acc: 0.8603
# Epoch 224/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3901 - acc: 0.8371 - val_loss: 0.3802 - val_acc: 0.8547
# Epoch 225/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3757 - acc: 0.8413 - val_loss: 0.3766 - val_acc: 0.8603
# Epoch 226/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3840 - acc: 0.8455 - val_loss: 0.3791 - val_acc: 0.8547
# Epoch 227/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3820 - acc: 0.8385 - val_loss: 0.3763 - val_acc: 0.8492
# Epoch 228/500
# 712/712 [==============================] - 0s 24us/step - loss: 0.3899 - acc: 0.8455 - val_loss: 0.3772 - val_acc: 0.8547
# Epoch 229/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3822 - acc: 0.8413 - val_loss: 0.3761 - val_acc: 0.8547
# Epoch 230/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3776 - acc: 0.8483 - val_loss: 0.3759 - val_acc: 0.8547
# Epoch 231/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3813 - acc: 0.8413 - val_loss: 0.3779 - val_acc: 0.8547
# Epoch 232/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3820 - acc: 0.8413 - val_loss: 0.3770 - val_acc: 0.8547
# Epoch 233/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3771 - acc: 0.8385 - val_loss: 0.3716 - val_acc: 0.8659
# Epoch 234/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3797 - acc: 0.8525 - val_loss: 0.3691 - val_acc: 0.8603
# Epoch 235/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3736 - acc: 0.8567 - val_loss: 0.3724 - val_acc: 0.8603
# Epoch 236/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3748 - acc: 0.8427 - val_loss: 0.3690 - val_acc: 0.8547
# Epoch 237/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3931 - acc: 0.8343 - val_loss: 0.3764 - val_acc: 0.8659
# Epoch 238/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3797 - acc: 0.8483 - val_loss: 0.3776 - val_acc: 0.8492
# Epoch 239/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3763 - acc: 0.8413 - val_loss: 0.3655 - val_acc: 0.8547
# Epoch 240/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3732 - acc: 0.8385 - val_loss: 0.3747 - val_acc: 0.8436
# Epoch 241/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3818 - acc: 0.8427 - val_loss: 0.3704 - val_acc: 0.8603
# Epoch 242/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3839 - acc: 0.8455 - val_loss: 0.3737 - val_acc: 0.8659
# Epoch 243/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3954 - acc: 0.8329 - val_loss: 0.3707 - val_acc: 0.8603
# Epoch 244/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3820 - acc: 0.8483 - val_loss: 0.3656 - val_acc: 0.8603
# Epoch 245/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3808 - acc: 0.8441 - val_loss: 0.3723 - val_acc: 0.8603
# Epoch 246/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3807 - acc: 0.8399 - val_loss: 0.3696 - val_acc: 0.8603
# Epoch 247/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3771 - acc: 0.8413 - val_loss: 0.3687 - val_acc: 0.8659
# Epoch 248/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3871 - acc: 0.8301 - val_loss: 0.3749 - val_acc: 0.8492
# Epoch 249/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3755 - acc: 0.8525 - val_loss: 0.3723 - val_acc: 0.8603
# Epoch 250/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3775 - acc: 0.8399 - val_loss: 0.3688 - val_acc: 0.8603
# Epoch 251/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3878 - acc: 0.8413 - val_loss: 0.3770 - val_acc: 0.8492
# Epoch 252/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.3797 - acc: 0.8455 - val_loss: 0.3748 - val_acc: 0.8547
# Epoch 253/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3808 - acc: 0.8357 - val_loss: 0.3835 - val_acc: 0.8547
# Epoch 254/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3836 - acc: 0.8525 - val_loss: 0.3797 - val_acc: 0.8547
# Epoch 255/500
# 712/712 [==============================] - 0s 40us/step - loss: 0.3769 - acc: 0.8441 - val_loss: 0.3776 - val_acc: 0.8547
# Epoch 256/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3756 - acc: 0.8413 - val_loss: 0.3702 - val_acc: 0.8659
# Epoch 257/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3777 - acc: 0.8455 - val_loss: 0.3752 - val_acc: 0.8603
# Epoch 258/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3633 - acc: 0.8483 - val_loss: 0.3776 - val_acc: 0.8603
# Epoch 259/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3857 - acc: 0.8413 - val_loss: 0.3741 - val_acc: 0.8603
# Epoch 260/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.4035 - acc: 0.8399 - val_loss: 0.3802 - val_acc: 0.8492
# Epoch 261/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3861 - acc: 0.8427 - val_loss: 0.3800 - val_acc: 0.8547
# Epoch 262/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3748 - acc: 0.8567 - val_loss: 0.3787 - val_acc: 0.8659
# Epoch 263/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3717 - acc: 0.8483 - val_loss: 0.3737 - val_acc: 0.8603
# Epoch 264/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3818 - acc: 0.8441 - val_loss: 0.3771 - val_acc: 0.8547
# Epoch 265/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3888 - acc: 0.8385 - val_loss: 0.3872 - val_acc: 0.8380
# Epoch 266/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3731 - acc: 0.8469 - val_loss: 0.3728 - val_acc: 0.8659
# Epoch 267/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3764 - acc: 0.8539 - val_loss: 0.3646 - val_acc: 0.8659
# Epoch 268/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3706 - acc: 0.8455 - val_loss: 0.3707 - val_acc: 0.8603
# Epoch 269/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3889 - acc: 0.8497 - val_loss: 0.3708 - val_acc: 0.8603
# Epoch 270/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3841 - acc: 0.8441 - val_loss: 0.3743 - val_acc: 0.8659
# Epoch 271/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3875 - acc: 0.8413 - val_loss: 0.3689 - val_acc: 0.8659
# Epoch 272/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3649 - acc: 0.8385 - val_loss: 0.3654 - val_acc: 0.8603
# Epoch 273/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3798 - acc: 0.8385 - val_loss: 0.3640 - val_acc: 0.8603
# Epoch 274/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3897 - acc: 0.8357 - val_loss: 0.3819 - val_acc: 0.8436
# Epoch 275/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3803 - acc: 0.8357 - val_loss: 0.3846 - val_acc: 0.8603
# Epoch 276/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3870 - acc: 0.8427 - val_loss: 0.3811 - val_acc: 0.8603
# Epoch 277/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3917 - acc: 0.8357 - val_loss: 0.3765 - val_acc: 0.8547
# Epoch 278/500
# 712/712 [==============================] - 0s 40us/step - loss: 0.3717 - acc: 0.8385 - val_loss: 0.3816 - val_acc: 0.8492
# Epoch 279/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3897 - acc: 0.8315 - val_loss: 0.3875 - val_acc: 0.8380
# Epoch 280/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3833 - acc: 0.8315 - val_loss: 0.3747 - val_acc: 0.8547
# Epoch 281/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3864 - acc: 0.8357 - val_loss: 0.3744 - val_acc: 0.8547
# Epoch 282/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3832 - acc: 0.8343 - val_loss: 0.3806 - val_acc: 0.8492
# Epoch 283/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3808 - acc: 0.8511 - val_loss: 0.3846 - val_acc: 0.8547
# Epoch 284/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3855 - acc: 0.8455 - val_loss: 0.3786 - val_acc: 0.8547
# Epoch 285/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3883 - acc: 0.8427 - val_loss: 0.3796 - val_acc: 0.8547
# Epoch 286/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3725 - acc: 0.8385 - val_loss: 0.3810 - val_acc: 0.8547
# Epoch 287/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3730 - acc: 0.8483 - val_loss: 0.3870 - val_acc: 0.8492
# Epoch 288/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3772 - acc: 0.8413 - val_loss: 0.3836 - val_acc: 0.8603
# Epoch 289/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3762 - acc: 0.8399 - val_loss: 0.3944 - val_acc: 0.8324
# Epoch 290/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3846 - acc: 0.8497 - val_loss: 0.3902 - val_acc: 0.8492
# Epoch 291/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3860 - acc: 0.8357 - val_loss: 0.3765 - val_acc: 0.8603
# Epoch 292/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3838 - acc: 0.8483 - val_loss: 0.3733 - val_acc: 0.8603
# Epoch 293/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3842 - acc: 0.8427 - val_loss: 0.3746 - val_acc: 0.8547
# Epoch 294/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3800 - acc: 0.8427 - val_loss: 0.3719 - val_acc: 0.8659
# Epoch 295/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3758 - acc: 0.8399 - val_loss: 0.3710 - val_acc: 0.8659
# Epoch 296/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3744 - acc: 0.8469 - val_loss: 0.3768 - val_acc: 0.8603
# Epoch 297/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3741 - acc: 0.8469 - val_loss: 0.3727 - val_acc: 0.8603
# Epoch 298/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3858 - acc: 0.8399 - val_loss: 0.3923 - val_acc: 0.8492
# Epoch 299/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3864 - acc: 0.8441 - val_loss: 0.3726 - val_acc: 0.8659
# Epoch 300/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3801 - acc: 0.8441 - val_loss: 0.3806 - val_acc: 0.8603
# Epoch 301/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.3838 - acc: 0.8525 - val_loss: 0.3758 - val_acc: 0.8659
# Epoch 302/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3616 - acc: 0.8497 - val_loss: 0.3713 - val_acc: 0.8659
# Epoch 303/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3730 - acc: 0.8497 - val_loss: 0.3754 - val_acc: 0.8603
# Epoch 304/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3636 - acc: 0.8596 - val_loss: 0.3685 - val_acc: 0.8603
# Epoch 305/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3861 - acc: 0.8399 - val_loss: 0.3722 - val_acc: 0.8603
# Epoch 306/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3723 - acc: 0.8455 - val_loss: 0.3721 - val_acc: 0.8547
# Epoch 307/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3695 - acc: 0.8539 - val_loss: 0.3803 - val_acc: 0.8547
# Epoch 308/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3708 - acc: 0.8413 - val_loss: 0.3810 - val_acc: 0.8492
# Epoch 309/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3642 - acc: 0.8469 - val_loss: 0.3817 - val_acc: 0.8492
# Epoch 310/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3677 - acc: 0.8553 - val_loss: 0.3725 - val_acc: 0.8603
# Epoch 311/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3753 - acc: 0.8399 - val_loss: 0.3802 - val_acc: 0.8659
# Epoch 312/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3719 - acc: 0.8483 - val_loss: 0.3748 - val_acc: 0.8659
# Epoch 313/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3678 - acc: 0.8539 - val_loss: 0.3776 - val_acc: 0.8659
# Epoch 314/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3857 - acc: 0.8399 - val_loss: 0.3723 - val_acc: 0.8603
# Epoch 315/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3767 - acc: 0.8427 - val_loss: 0.3792 - val_acc: 0.8603
# Epoch 316/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3619 - acc: 0.8539 - val_loss: 0.3816 - val_acc: 0.8547
# Epoch 317/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3766 - acc: 0.8357 - val_loss: 0.3813 - val_acc: 0.8659
# Epoch 318/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3694 - acc: 0.8525 - val_loss: 0.3886 - val_acc: 0.8547
# Epoch 319/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3769 - acc: 0.8399 - val_loss: 0.3941 - val_acc: 0.8547
# Epoch 320/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3703 - acc: 0.8455 - val_loss: 0.3811 - val_acc: 0.8492
# Epoch 321/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3592 - acc: 0.8469 - val_loss: 0.3854 - val_acc: 0.8380
# Epoch 322/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3638 - acc: 0.8539 - val_loss: 0.3821 - val_acc: 0.8436
# Epoch 323/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3699 - acc: 0.8539 - val_loss: 0.3776 - val_acc: 0.8492
# Epoch 324/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3832 - acc: 0.8539 - val_loss: 0.3699 - val_acc: 0.8659
# Epoch 325/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3732 - acc: 0.8469 - val_loss: 0.3896 - val_acc: 0.8603
# Epoch 326/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3696 - acc: 0.8497 - val_loss: 0.3841 - val_acc: 0.8603
# Epoch 327/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3728 - acc: 0.8427 - val_loss: 0.3733 - val_acc: 0.8603
# Epoch 328/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3704 - acc: 0.8539 - val_loss: 0.3820 - val_acc: 0.8547
# Epoch 329/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3796 - acc: 0.8455 - val_loss: 0.3815 - val_acc: 0.8492
# Epoch 330/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3863 - acc: 0.8371 - val_loss: 0.3772 - val_acc: 0.8603
# Epoch 331/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3860 - acc: 0.8455 - val_loss: 0.3807 - val_acc: 0.8547
# Epoch 332/500
# 712/712 [==============================] - 0s 43us/step - loss: 0.3922 - acc: 0.8357 - val_loss: 0.3772 - val_acc: 0.8492
# Epoch 333/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3858 - acc: 0.8413 - val_loss: 0.3856 - val_acc: 0.8603
# Epoch 334/500
# 712/712 [==============================] - 0s 42us/step - loss: 0.3744 - acc: 0.8469 - val_loss: 0.3759 - val_acc: 0.8659
# Epoch 335/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3776 - acc: 0.8511 - val_loss: 0.3708 - val_acc: 0.8492
# Epoch 336/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.3633 - acc: 0.8567 - val_loss: 0.3747 - val_acc: 0.8603
# Epoch 337/500
# 712/712 [==============================] - 0s 39us/step - loss: 0.3720 - acc: 0.8483 - val_loss: 0.3774 - val_acc: 0.8603
# Epoch 338/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3680 - acc: 0.8511 - val_loss: 0.3840 - val_acc: 0.8659
# Epoch 339/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3664 - acc: 0.8525 - val_loss: 0.3824 - val_acc: 0.8492
# Epoch 340/500
# 712/712 [==============================] - 0s 40us/step - loss: 0.3848 - acc: 0.8385 - val_loss: 0.3871 - val_acc: 0.8492
# Epoch 341/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3694 - acc: 0.8413 - val_loss: 0.3842 - val_acc: 0.8547
# Epoch 342/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3840 - acc: 0.8427 - val_loss: 0.3827 - val_acc: 0.8492
# Epoch 343/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3695 - acc: 0.8455 - val_loss: 0.3931 - val_acc: 0.8380
# Epoch 344/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3750 - acc: 0.8497 - val_loss: 0.3822 - val_acc: 0.8547
# Epoch 345/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3634 - acc: 0.8567 - val_loss: 0.3902 - val_acc: 0.8492
# Epoch 346/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3649 - acc: 0.8511 - val_loss: 0.3860 - val_acc: 0.8492
# Epoch 347/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3620 - acc: 0.8497 - val_loss: 0.3849 - val_acc: 0.8492
# Epoch 348/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3773 - acc: 0.8357 - val_loss: 0.3778 - val_acc: 0.8547
# Epoch 349/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3662 - acc: 0.8539 - val_loss: 0.3782 - val_acc: 0.8547
# Epoch 350/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3759 - acc: 0.8469 - val_loss: 0.3774 - val_acc: 0.8547
# Epoch 351/500
# 712/712 [==============================] - 0s 42us/step - loss: 0.3772 - acc: 0.8511 - val_loss: 0.3696 - val_acc: 0.8603
# Epoch 352/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3792 - acc: 0.8399 - val_loss: 0.3693 - val_acc: 0.8547
# Epoch 353/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3744 - acc: 0.8413 - val_loss: 0.3811 - val_acc: 0.8547
# Epoch 354/500
# ...
# Epoch 384/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3776 - acc: 0.8469 - val_loss: 0.3776 - val_acc: 0.8603
# Epoch 385/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3626 - acc: 0.8455 - val_loss: 0.3767 - val_acc: 0.8547
# Epoch 386/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3782 - acc: 0.8469 - val_loss: 0.3779 - val_acc: 0.8492
# Epoch 387/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3756 - acc: 0.8469 - val_loss: 0.3745 - val_acc: 0.8492
# Epoch 388/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3756 - acc: 0.8413 - val_loss: 0.3748 - val_acc: 0.8603
# Epoch 389/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3732 - acc: 0.8497 - val_loss: 0.3859 - val_acc: 0.8436
# Epoch 390/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3657 - acc: 0.8539 - val_loss: 0.3784 - val_acc: 0.8492
# Epoch 391/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3522 - acc: 0.8469 - val_loss: 0.3824 - val_acc: 0.8380
# Epoch 392/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3660 - acc: 0.8553 - val_loss: 0.3848 - val_acc: 0.8436
# Epoch 393/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3634 - acc: 0.8455 - val_loss: 0.3805 - val_acc: 0.8436
# Epoch 394/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3569 - acc: 0.8553 - val_loss: 0.3821 - val_acc: 0.8492
# Epoch 395/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3537 - acc: 0.8610 - val_loss: 0.3794 - val_acc: 0.8436
# Epoch 396/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.3586 - acc: 0.8567 - val_loss: 0.3785 - val_acc: 0.8436
# Epoch 397/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3675 - acc: 0.8469 - val_loss: 0.3772 - val_acc: 0.8492
# Epoch 398/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3613 - acc: 0.8469 - val_loss: 0.3840 - val_acc: 0.8380
# Epoch 399/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3632 - acc: 0.8483 - val_loss: 0.3880 - val_acc: 0.8492
# Epoch 400/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3608 - acc: 0.8525 - val_loss: 0.3829 - val_acc: 0.8492
# Epoch 401/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3727 - acc: 0.8413 - val_loss: 0.3924 - val_acc: 0.8436
# Epoch 402/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3651 - acc: 0.8483 - val_loss: 0.3917 - val_acc: 0.8547
# Epoch 403/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3616 - acc: 0.8483 - val_loss: 0.3972 - val_acc: 0.8547
# Epoch 404/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3706 - acc: 0.8455 - val_loss: 0.3807 - val_acc: 0.8603
# Epoch 405/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3680 - acc: 0.8497 - val_loss: 0.3834 - val_acc: 0.8603
# Epoch 406/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3725 - acc: 0.8581 - val_loss: 0.3836 - val_acc: 0.8436
# Epoch 407/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3641 - acc: 0.8567 - val_loss: 0.3794 - val_acc: 0.8436
# Epoch 408/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3535 - acc: 0.8610 - val_loss: 0.3812 - val_acc: 0.8547
# Epoch 409/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3713 - acc: 0.8511 - val_loss: 0.3797 - val_acc: 0.8547
# Epoch 410/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3589 - acc: 0.8525 - val_loss: 0.3669 - val_acc: 0.8603
# Epoch 411/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3674 - acc: 0.8525 - val_loss: 0.3693 - val_acc: 0.8603
# Epoch 412/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3659 - acc: 0.8525 - val_loss: 0.3728 - val_acc: 0.8547
# Epoch 413/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3607 - acc: 0.8525 - val_loss: 0.3784 - val_acc: 0.8603
# Epoch 414/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3544 - acc: 0.8581 - val_loss: 0.3783 - val_acc: 0.8492
# Epoch 415/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3478 - acc: 0.8567 - val_loss: 0.3716 - val_acc: 0.8547
# Epoch 416/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3731 - acc: 0.8455 - val_loss: 0.3661 - val_acc: 0.8715
# Epoch 417/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3581 - acc: 0.8483 - val_loss: 0.3718 - val_acc: 0.8603
# Epoch 418/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3631 - acc: 0.8511 - val_loss: 0.3715 - val_acc: 0.8603
# Epoch 419/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3643 - acc: 0.8441 - val_loss: 0.3739 - val_acc: 0.8659
# Epoch 420/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3516 - acc: 0.8483 - val_loss: 0.3807 - val_acc: 0.8492
# Epoch 421/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3534 - acc: 0.8581 - val_loss: 0.3768 - val_acc: 0.8436
# Epoch 422/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3629 - acc: 0.8525 - val_loss: 0.3808 - val_acc: 0.8436
# Epoch 423/500
# 712/712 [==============================] - 0s 24us/step - loss: 0.3549 - acc: 0.8567 - val_loss: 0.3769 - val_acc: 0.8436
# Epoch 424/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3684 - acc: 0.8497 - val_loss: 0.3719 - val_acc: 0.8603
# Epoch 425/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3642 - acc: 0.8525 - val_loss: 0.3670 - val_acc: 0.8659
# Epoch 426/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3599 - acc: 0.8483 - val_loss: 0.3733 - val_acc: 0.8603
# Epoch 427/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3583 - acc: 0.8497 - val_loss: 0.3844 - val_acc: 0.8547
# Epoch 428/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3507 - acc: 0.8666 - val_loss: 0.3737 - val_acc: 0.8492
# Epoch 429/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3687 - acc: 0.8581 - val_loss: 0.3742 - val_acc: 0.8436
# Epoch 430/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3629 - acc: 0.8511 - val_loss: 0.3659 - val_acc: 0.8547
# Epoch 431/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3644 - acc: 0.8399 - val_loss: 0.3702 - val_acc: 0.8380
# Epoch 432/500
# 712/712 [==============================] - 0s 23us/step - loss: 0.3834 - acc: 0.8469 - val_loss: 0.3824 - val_acc: 0.8492
# Epoch 433/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3596 - acc: 0.8596 - val_loss: 0.3623 - val_acc: 0.8715
# Epoch 434/500
# 712/712 [==============================] - 0s 25us/step - loss: 0.3581 - acc: 0.8581 - val_loss: 0.3591 - val_acc: 0.8659
# Epoch 435/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3636 - acc: 0.8525 - val_loss: 0.3812 - val_acc: 0.8492
# Epoch 436/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3657 - acc: 0.8553 - val_loss: 0.3704 - val_acc: 0.8603
# Epoch 437/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.3610 - acc: 0.8525 - val_loss: 0.3710 - val_acc: 0.8603
# Epoch 438/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3648 - acc: 0.8441 - val_loss: 0.3678 - val_acc: 0.8603
# Epoch 439/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3582 - acc: 0.8596 - val_loss: 0.3737 - val_acc: 0.8492
# Epoch 440/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3480 - acc: 0.8539 - val_loss: 0.3749 - val_acc: 0.8492
# Epoch 441/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3659 - acc: 0.8497 - val_loss: 0.3804 - val_acc: 0.8547
# Epoch 442/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3598 - acc: 0.8567 - val_loss: 0.3770 - val_acc: 0.8603
# Epoch 443/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3773 - acc: 0.8553 - val_loss: 0.3738 - val_acc: 0.8380
# Epoch 444/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3726 - acc: 0.8455 - val_loss: 0.3784 - val_acc: 0.8547
# Epoch 445/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3649 - acc: 0.8399 - val_loss: 0.3811 - val_acc: 0.8547
# Epoch 446/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3672 - acc: 0.8455 - val_loss: 0.3898 - val_acc: 0.8380
# Epoch 447/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3659 - acc: 0.8441 - val_loss: 0.3767 - val_acc: 0.8492
# Epoch 448/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3659 - acc: 0.8581 - val_loss: 0.3749 - val_acc: 0.8492
# Epoch 449/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3544 - acc: 0.8567 - val_loss: 0.3697 - val_acc: 0.8492
# Epoch 450/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3629 - acc: 0.8581 - val_loss: 0.3726 - val_acc: 0.8492
# Epoch 451/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3590 - acc: 0.8581 - val_loss: 0.3788 - val_acc: 0.8547
# Epoch 452/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3590 - acc: 0.8539 - val_loss: 0.3887 - val_acc: 0.8492
# Epoch 453/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3557 - acc: 0.8441 - val_loss: 0.3874 - val_acc: 0.8603
# Epoch 454/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3638 - acc: 0.8497 - val_loss: 0.3789 - val_acc: 0.8547
# Epoch 455/500
# 712/712 [==============================] - 0s 29us/step - loss: 0.3548 - acc: 0.8539 - val_loss: 0.3830 - val_acc: 0.8492
# Epoch 456/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3660 - acc: 0.8525 - val_loss: 0.3928 - val_acc: 0.8436
# Epoch 457/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3795 - acc: 0.8483 - val_loss: 0.4038 - val_acc: 0.8436
# Epoch 458/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3720 - acc: 0.8511 - val_loss: 0.3852 - val_acc: 0.8436
# Epoch 459/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3620 - acc: 0.8624 - val_loss: 0.3827 - val_acc: 0.8492
# Epoch 460/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3557 - acc: 0.8469 - val_loss: 0.3890 - val_acc: 0.8492
# Epoch 461/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3628 - acc: 0.8525 - val_loss: 0.3858 - val_acc: 0.8436
# Epoch 462/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3584 - acc: 0.8553 - val_loss: 0.3843 - val_acc: 0.8324
# Epoch 463/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3585 - acc: 0.8553 - val_loss: 0.3807 - val_acc: 0.8436
# Epoch 464/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3540 - acc: 0.8539 - val_loss: 0.3736 - val_acc: 0.8603
# Epoch 465/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3667 - acc: 0.8567 - val_loss: 0.3812 - val_acc: 0.8603
# Epoch 466/500
# 712/712 [==============================] - 0s 25us/step - loss: 0.3580 - acc: 0.8441 - val_loss: 0.3855 - val_acc: 0.8492
# Epoch 467/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3729 - acc: 0.8469 - val_loss: 0.3765 - val_acc: 0.8603
# Epoch 468/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3623 - acc: 0.8427 - val_loss: 0.3891 - val_acc: 0.8324
# Epoch 469/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3739 - acc: 0.8413 - val_loss: 0.3927 - val_acc: 0.8380
# Epoch 470/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3824 - acc: 0.8343 - val_loss: 0.3904 - val_acc: 0.8436
# Epoch 471/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3675 - acc: 0.8441 - val_loss: 0.3817 - val_acc: 0.8492
# Epoch 472/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3671 - acc: 0.8441 - val_loss: 0.3818 - val_acc: 0.8547
# Epoch 473/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3808 - acc: 0.8455 - val_loss: 0.3962 - val_acc: 0.8492
# Epoch 474/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3710 - acc: 0.8455 - val_loss: 0.3836 - val_acc: 0.8547
# Epoch 475/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3810 - acc: 0.8469 - val_loss: 0.3867 - val_acc: 0.8492
# Epoch 476/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3654 - acc: 0.8483 - val_loss: 0.3828 - val_acc: 0.8492
# Epoch 477/500
# 712/712 [==============================] - 0s 35us/step - loss: 0.3537 - acc: 0.8539 - val_loss: 0.3861 - val_acc: 0.8492
# Epoch 478/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3717 - acc: 0.8483 - val_loss: 0.3863 - val_acc: 0.8547
# Epoch 479/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3711 - acc: 0.8469 - val_loss: 0.3833 - val_acc: 0.8547
# Epoch 480/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3578 - acc: 0.8441 - val_loss: 0.3775 - val_acc: 0.8659
# Epoch 481/500
# 712/712 [==============================] - 0s 38us/step - loss: 0.3687 - acc: 0.8399 - val_loss: 0.3790 - val_acc: 0.8547
# Epoch 482/500
# 712/712 [==============================] - 0s 37us/step - loss: 0.3575 - acc: 0.8469 - val_loss: 0.3849 - val_acc: 0.8492
# Epoch 483/500
# 712/712 [==============================] - 0s 42us/step - loss: 0.3741 - acc: 0.8413 - val_loss: 0.3853 - val_acc: 0.8492
# Epoch 484/500
# 712/712 [==============================] - 0s 26us/step - loss: 0.3635 - acc: 0.8469 - val_loss: 0.3839 - val_acc: 0.8603
# Epoch 485/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.3602 - acc: 0.8497 - val_loss: 0.3920 - val_acc: 0.8436
# Epoch 486/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3663 - acc: 0.8483 - val_loss: 0.3917 - val_acc: 0.8492
# Epoch 487/500
# 712/712 [==============================] - 0s 34us/step - loss: 0.3625 - acc: 0.8497 - val_loss: 0.3838 - val_acc: 0.8547
# Epoch 488/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3804 - acc: 0.8469 - val_loss: 0.3991 - val_acc: 0.8324
# Epoch 489/500
# 712/712 [==============================] - 0s 36us/step - loss: 0.3655 - acc: 0.8399 - val_loss: 0.3974 - val_acc: 0.8492
# Epoch 490/500
# 712/712 [==============================] - 0s 33us/step - loss: 0.3638 - acc: 0.8539 - val_loss: 0.3883 - val_acc: 0.8380
# Epoch 491/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3629 - acc: 0.8497 - val_loss: 0.3917 - val_acc: 0.8492
# Epoch 492/500
# 712/712 [==============================] - 0s 28us/step - loss: 0.3688 - acc: 0.8413 - val_loss: 0.3932 - val_acc: 0.8380
# Epoch 493/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3698 - acc: 0.8483 - val_loss: 0.3924 - val_acc: 0.8436
# Epoch 494/500
# 712/712 [==============================] - 0s 30us/step - loss: 0.3582 - acc: 0.8455 - val_loss: 0.3908 - val_acc: 0.8436
# Epoch 495/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3736 - acc: 0.8371 - val_loss: 0.3874 - val_acc: 0.8436
# Epoch 496/500
# 712/712 [==============================] - 0s 31us/step - loss: 0.3642 - acc: 0.8511 - val_loss: 0.3887 - val_acc: 0.8380
# Epoch 497/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3661 - acc: 0.8539 - val_loss: 0.3816 - val_acc: 0.8603
# Epoch 498/500
# 712/712 [==============================] - 0s 32us/step - loss: 0.3478 - acc: 0.8553 - val_loss: 0.3880 - val_acc: 0.8380
# Epoch 499/500
# 712/712 [==============================] - 0s 41us/step - loss: 0.3697 - acc: 0.8497 - val_loss: 0.3906 - val_acc: 0.8492
# Epoch 500/500
# 712/712 [==============================] - 0s 27us/step - loss: 0.3651 - acc: 0.8469 - val_loss: 0.3878 - val_acc: 0.8436

# %%
hists = [history]
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_acc, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.acc, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_loss, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.loss, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
fig.savefig('hist.png', dpi=300)
plt.show();

# %% [markdown]
# ## 5. 모델 예측 및 평가
# ---
#
# 이제 모델이 학습하지 않았던(보지 않았던) 테스트셋을 모델에 주어서, 생존여부를 예측
# 이 결과는 실제로 submission(제출용) 이므로 결과는 leaderboard 에서 확인할 수 있습니다.
# 캐글에서 준 파일, gender_submission.csv 파일을 읽어서 제출 준비를 하겠습니다

# %%
submission = pd.read_csv('../input/sample_submission.csv')
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
prediction = model.predict(X_test)
submission['Survived'] = prediction

# %%
submission.to_csv('my_first_submission.csv', index=False)

# %% [markdown]
# **0.75598** 정확도 스코어

# %% [markdown]
# ## 5.B NN 예측 및 평가

# %%
submission = pd.read_csv('../input/sample_submission.csv')
prediction = nn_model.predict(X_test)
prediction = prediction > 0.5
prediction = prediction.astype(np.int)
prediction = prediction.T[0]
prediction.shape
# Out:
# (418,)

# %%
submission['Survived'] = prediction
submission.to_csv('my_nn_submission.csv', index=False)

# %% [markdown]
# **0.77990** 정확도 스코어

# %% [markdown]
# ## 7. 어떻게 공부하는게 좋을까요?
# ---
#
# 처음 시작할 때 많은 답답했던 부분이 이거였습니다.
# 사실 아직도 답은 못찾았고, 답은 없는 것 같습니다.
# 하지만 제가 주로 어떻게 하는지 알려드리자면,
#
# * 일단 캐글 대회 참여해본다.
#     * 캐글 대회를 참여하고, 여러 분석한 커널들을 보면 다양한 최신 기술과 문제를 접근하는 방법을 배우게 됩니다.
#
# * 모르는 코드는 print하면서 분석하고, 안보고 다시 적어본다.
#     * 모르는 코드는 어느정도 분석하는 시간을 가져야 합니다.
#
# * 모르는 함수는 공식 API 문서를 본다.
#     * sklearn, tensorflow, pandas, keras.. 와같은 유명 패키지들은 공식 문서가 상당히 잘 되어있습니다.
#     * 해당 함수는 여러 파라미터를 가지고 있는데 하나하나 보면서 어떤 역할을 하는지 훑어만 봐도 나중에 활용할 때 도움이 되었습니다.
#
# * 기본 공부도 병행한다.
#     * 요즘 너무나도 좋은 강의, 책들이 많습니다. 이걸 보시면서 공부하시면 더 도움이 될 것 같습니다.
#
# * 그래도 모르겠다면 구글링, github...
#     * 많은 블로그, 많은 오픈소스 안에 훌륭한 예제와 설명이 많습니다.
#     빠르게 접근하기에 이만한 방법도 없을 것 같습니다.

# %% [markdown]
# ### **강의 리스트**
# * [최성철 교수님 : 머신러닝을 위한 Python 워밍업](https://www.edwith.org/aipython)
#     * 처음 판다스, 넘파이 와 같은 라이브러리를 배우기에 좋았습니다.
# * [김성훈 교수님 : 머신러닝과 딥러닝 BASIC](https://www.edwith.org/others26)
#     * 처음 텐서플로우로 딥러닝 입문하는데 너무 좋았습니다.
# * [Andrew Ng 교수님 : 오픈 코세라 강의](https://www.youtube.com/channel/UCcIXc5mJsHVYTZR1maL5l9w/playlists)
#     * 기본부터 찬찬히 공부하기에 너무 좋은 강의 입니다.
#     강의 절반은 한글화가 되어 있으니 접근하시는데 무리가 없을 것입니다!

# %% [markdown]
# ### **책 리스트**
#
# * 파이썬 라이브러리를 활용한 머신러닝(Introduction to machine larning with Python)
#     * 처음 캐글 코리아 분들과 스터디한 책입니다. 빠르게 캐글에 입문할 수 있도록 만든 책입니다.
# * 핸즈온 머신러닝
#     * 어렵긴 하지만 하나하나 도움이 되는 책인 것 같습니다. 아직 공부 중입니다...
# * 밑바닥 부터 시작하는 딥러닝
#     * 직접 파이썬으로 딥러닝 학습과정부터 한땀 한땀 구현하는게 재미있었습니다.
#     구현하면서 배우는 걸 좋아하시는 분에게 추천해드립니다.
